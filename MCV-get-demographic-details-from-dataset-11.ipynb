# %% [markdown]
# # Working with accent data in the Mozilla Common Voice dataset
#
# The purpose of this Python Jupyter notebook is to provide some worked examples of how you might explore accent data in the Common Voice dataset.

# %% [markdown]
# ## Index of notebook contents
#
# To make this notebook easier to navigate, each section is indexed below.
#
# * [Background information on demographic data in Common Voice](#Background)
# * [Preparation steps and importing modules](#PreparationSteps) - including the `requirements.txt` you should run if using this notebook.
# * [The Accent and AccentDescriptor classes we will use in the notebook](#Classes)
# * [Preparing data from the Common Voice TSV file](#PreparingData)
# * [Extracting accent information for data visualisation](#AccentExtraction)
# * [Determine which accents are predetermined for selection in the Common Voice profile screen](#PreDetermined)
# * [Add Descriptors to each Accent](#Descriptors)

# %% [markdown]
# ---
# <a id='Background'></a>
# ## Background information on demographic data in Common Voice
#
# Before you start working with accent data in Common Voice, there is background information you should know about the data structures in the Common Voice datasets, and how accents have been represented.
#
# ### The ability to choose whether or not to specify demographic information
#
# Data contributors can contribute voice data to Common Voice with our without logging in to the platform. If a data contributor is not logged in, the utterances they record contain no demographic metadata information, such as the gender, age range or accent of the speaker. If the data contributor _does_ log in, then they can choose whether to specify demographic information in their profile. Part of the demographic information can include specifying which accent(s) they speak with.
#
#
# Since mid 2021, data contributors to the Common Voice dataset have been able to self-specify descriptors for their accents.
#
# The purpose of this script is to get demographic details from an MCV downloaded dataset.
# This informs decision making around, for example, how much of the data in a particular language, has demographic details, and if so, what they are.

# %% [markdown]
# ---
# <a id='PreparationSteps'></a>
#
# ## Preparation steps and importing the modules we will use
#
# @TODO
#
# make a `requirements.txt` file to install all the dependencies.
#
# * pandas

# %%
# imports go here 

# io 
import io

# pandas 
import pandas as pd

# regular expressions 
import re

# json 
import json

# pretty print 
import pprint
pp = pprint.PrettyPrinter(indent=4)

# reload = because I'm developing the CVaccents module as I go, I want to reload it each time so it doesn't cache
from importlib import reload

# %% [markdown]
# ---
# <a id='Classes'></a>
# ## Accent and AccentDescriptor classes used for manipulation

# %%
## Accent class and AccentDescriptor class 

# these are classes I defined for accent handling
import cvaccents as cva

# do an explicit reload as I'm still working on the classes 
reload(cva)

# prove that my DocStrings are useful
# they are good, so I am suppressing output while I work through the rest of the doc. 

#print('Module docstring is: \n', cva.__doc__)
#print('---')
#print('Accent docstring is: \n', cva.Accent.__doc__)
#print('---')
#print('AccentDescriptor docstring is: \n', cva.AccentDescriptor.__doc__)
#print('---')
# Out:
# <module 'cvaccents' from '/home/users/u6933485/cv-analysis-for-bias/cvaccents.py'>

# %% [markdown]
# ---
# <a id='PreparingData'></a>
# ## Preparing the data from the Common Voice dataset TSV file
#
# Here, we extract data from the TSV file, and use `pandas` to perform manipulations on the dataset, such as removing rows that do not contain accent metadata.

# %%
# specify the path to the TSV file - this should be `validated.tsv` from the MCV download 
#filePath = '/media/kathyreid/Seagate Backup Plus Drive/cv-datasets/ru/validated.tsv'
#filePath = '/media/kathyreid/Seagate Backup Plus Drive/cv-datasets/fr/validated.tsv'
#filePath = '/media/kathyreid/Elements/de/validated.tsv'
#filePath = '/media/kathyreid/Elements/es/validated.tsv'
#filePath = '/media/kathyreid/Elements/en/validated.tsv'
#filePath = '/media/kathyreid/Seagate Backup Plus Drive/cv-datasets/en-v9/validated.tsv'
filePath = '../cv-datasets/cv-corpus-11.0-2022-09-21/en/validated.tsv'

# put it into a DataFrame 
df = pd.read_csv(filePath, sep='\t')

# %%
df.columns
# Out:
# Index(['client_id', 'path', 'sentence', 'up_votes', 'down_votes', 'age',
#        'gender', 'accents', 'locale', 'segment'],
#       dtype='object')

# %%
# We don't want all the columns, as some of them are not useful for the accent analysis 
# Drop the columns we don't want 

df.drop(labels=['path', 'sentence', 'up_votes', 'down_votes', 'segment', 'locale'], axis='columns', inplace=True)
df.columns
# Out:
# Index(['client_id', 'age', 'gender', 'accents'], dtype='object')

# %%
len(df)
# Out:
# 1617877

# %%
# rows that have accent metadata 
len(df[df['accents'].notna()])
# Out:
# 861134

# %%
# remove all the rows where accents are not given (NaN)
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
# DataFrame.dropna(*, axis=0, how=_NoDefault.no_default, thresh=_NoDefault.no_default, subset=None, inplace=False)

df.dropna(axis='index', how='any', subset='accents', inplace=True)
len(df)

# this matches the above figure for rows that have accent metadata, so it's a good cross-check
# Out:
# 861134

# %%
# number of unique contributors to the dataset 
len(df['client_id'].unique())
# Out:
# 14822

# %%
# Now that the rows without an accent value have been removed, 
# we want to deduplicate the speaker_id values - because one speaker can speak many utterances
# and we only want to record one accent per speaker 
# and we should end up with the # of rows in the cell above 


# One of the reasons we try and reduce the size of the dataframe 
# first is because this operation is more efficient on a smaller dataframe 
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html
# DataFrame.drop_duplicates(subset=None, *, keep='first', inplace=False, ignore_index=False)

df.drop_duplicates(subset='client_id', keep='first', inplace=True)
len(df)

# This length should match the length above
# Out:
# 14822

# %% [markdown]
# ---
# <a id='AccentExtraction'></a>
# ## Extracting the accent data for visualisation
#
# We have already:
#
# * Removed any rows where accent data was not available = `NaN`
# * De-duplicated based on the `client_id`
#
# So now, we need to extract all the self-styled accents for analysis.

# %%
"""

The list english_accents_list is a list that contains the ORIGINAL accent entries for each speaker. 
In this list, the accents for each speaker are represented as a SINGLE STRING, NOT as a list of strings. 

So, we want to turn this into a LIST of LISTS OF STRINGS, to make it easier for doing data cleaning. 
Each individual string represents one accent descriptor given by a speaker, 
and the list which contains those strings is the grouping of accent descriptors for that speaker. 

We need to preserve the association between accent descriptors - co-references - for later data visualisation. 

"""

# They are already unique so we don't need the `.unique` method
english_accents = df['accents']

english_accents_list = [] 

for idx, accent_string in list(enumerate(english_accents)): 
    
    # this regex is from 
    # https://stackoverflow.com/questions/26633452/how-to-split-by-commas-that-are-not-within-parentheses
    accent_list=re.split(',\s*(?![^()]*\))', accent_string)
    
    
    for accent in accent_list: 
        
        print('idx is: ', idx, ' and accent_list is: ', accent_list)
        
        # Trim any whitespace off the elements, because this makes matching on strings harder later on 
        accent = accent.strip()
        
        # Check for any empty strings and remove them - likely regex artefacts
        if not accent: 
            accent_list.remove(accent)
        
        
    english_accents_list.append(accent_list)
# Out:
# idx is:  0  and accent_list is:  ['England English', 'United States English']
# idx is:  0  and accent_list is:  ['England English', 'United States English']
# idx is:  1  and accent_list is:  ['Hong Kong English']
# idx is:  2  and accent_list is:  ['England English']
# idx is:  3  and accent_list is:  ['United States English']
# idx is:  4  and accent_list is:  ['United States English', 'wolof']
# idx is:  4  and accent_list is:  ['United States English', 'wolof']
# idx is:  5  and accent_list is:  ['England English']
# idx is:  6  and accent_list is:  ['Australian English']
# idx is:  7  and accent_list is:  ['United States English']
# idx is:  8  and accent_list is:  ['Latin America', 'United States English']
# idx is:  8  and accent_list is:  ['Latin America', 'United States English']
# idx is:  9  and accent_list is:  ['United States English']
# idx is:  10  and accent_list is:  ['United States English']
# idx is:  11  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  12  and accent_list is:  ['United States English']
# idx is:  13  and accent_list is:  ['United States English']
# idx is:  14  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  15  and accent_list is:  ['United States English']
# idx is:  16  and accent_list is:  ['United States English']
# idx is:  17  and accent_list is:  ['England English']
# idx is:  18  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  19  and accent_list is:  ['England English']
# idx is:  20  and accent_list is:  ['United States English']
# idx is:  21  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  22  and accent_list is:  ['Australian English']
# idx is:  23  and accent_list is:  ['England English']
# idx is:  24  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  25  and accent_list is:  ['United States English']
# idx is:  26  and accent_list is:  ['United States English', 'Colombia']
# idx is:  26  and accent_list is:  ['United States English', 'Colombia']
# idx is:  27  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  28  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  29  and accent_list is:  ['United States English']
# idx is:  30  and accent_list is:  ['United States English']
# idx is:  31  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  32  and accent_list is:  ['Canadian English']
# idx is:  33  and accent_list is:  ['United States English']
# idx is:  34  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  35  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  36  and accent_list is:  ['United States English']
# idx is:  37  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  38  and accent_list is:  ['United States English']
# idx is:  39  and accent_list is:  ['Hong Kong English']
# idx is:  40  and accent_list is:  ['United States English']
# idx is:  41  and accent_list is:  ['England English']
# idx is:  42  and accent_list is:  ['England English']
# idx is:  43  and accent_list is:  ['United States English']
# idx is:  44  and accent_list is:  ['England English']
# idx is:  45  and accent_list is:  ['United States English']
# idx is:  46  and accent_list is:  ['England English']
# idx is:  47  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  48  and accent_list is:  ['United States English']
# idx is:  49  and accent_list is:  ['England English']
# idx is:  50  and accent_list is:  ['United States English']
# idx is:  51  and accent_list is:  ['England English']
# idx is:  52  and accent_list is:  ['United States English']
# idx is:  53  and accent_list is:  ['Non native speaker from France']
# idx is:  54  and accent_list is:  ['United States English']
# idx is:  55  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  56  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  57  and accent_list is:  ['United States English']
# idx is:  58  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  59  and accent_list is:  ['Australian English']
# idx is:  60  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  61  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  62  and accent_list is:  ['United States English']
# idx is:  63  and accent_list is:  ['England English']
# idx is:  64  and accent_list is:  ['Scottish English']
# idx is:  65  and accent_list is:  ['United States English']
# idx is:  66  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  67  and accent_list is:  ['United States English']
# idx is:  68  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  69  and accent_list is:  ['United States English']
# idx is:  70  and accent_list is:  ['United States English']
# idx is:  71  and accent_list is:  ['United States English']
# idx is:  72  and accent_list is:  ['England English']
# idx is:  73  and accent_list is:  ['New York City']
# idx is:  74  and accent_list is:  ['Hong Kong English']
# idx is:  75  and accent_list is:  ['England English']
# idx is:  76  and accent_list is:  ['United States English']
# idx is:  77  and accent_list is:  ['England English']
# idx is:  78  and accent_list is:  ['United States English']
# idx is:  79  and accent_list is:  ['United States English']
# idx is:  80  and accent_list is:  ['Filipino']
# idx is:  81  and accent_list is:  ['French']
# idx is:  82  and accent_list is:  ['United States English']
# idx is:  83  and accent_list is:  ['United States English']
# idx is:  84  and accent_list is:  ['Argentinian English']
# idx is:  85  and accent_list is:  ['United States English']
# idx is:  86  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  87  and accent_list is:  ['United States English']
# idx is:  88  and accent_list is:  ['Australian English']
# idx is:  89  and accent_list is:  ['Scottish English']
# idx is:  90  and accent_list is:  ['United States English']
# idx is:  91  and accent_list is:  ['United States English']
# idx is:  92  and accent_list is:  ['United States English']
# idx is:  93  and accent_list is:  ['United States English']
# idx is:  94  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  95  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  96  and accent_list is:  ['United States English']
# idx is:  97  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  98  and accent_list is:  ["A'lo"]
# idx is:  99  and accent_list is:  ['United States English']
# idx is:  100  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  101  and accent_list is:  ['United States English']
# idx is:  102  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  103  and accent_list is:  ['United States English']
# idx is:  104  and accent_list is:  ['United States English']
# idx is:  105  and accent_list is:  ['United States English']
# idx is:  106  and accent_list is:  ['United States English']
# idx is:  107  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  108  and accent_list is:  ['United States English']
# idx is:  109  and accent_list is:  ['United States English']
# idx is:  110  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  111  and accent_list is:  ['Canadian English']
# idx is:  112  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  113  and accent_list is:  ['England English']
# idx is:  114  and accent_list is:  ['United States English']
# idx is:  115  and accent_list is:  ['United States English']
# idx is:  116  and accent_list is:  ['United States English']
# idx is:  117  and accent_list is:  ['United States English']
# idx is:  118  and accent_list is:  ['United States English']
# idx is:  119  and accent_list is:  ['United States English']
# idx is:  120  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  121  and accent_list is:  ['United States English']
# idx is:  122  and accent_list is:  ['United States English']
# idx is:  123  and accent_list is:  ['United States English']
# idx is:  124  and accent_list is:  ['Finnish']
# idx is:  125  and accent_list is:  ['United States English']
# idx is:  126  and accent_list is:  ['United States English', 'India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  126  and accent_list is:  ['United States English', 'India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  127  and accent_list is:  ['Singaporean English']
# idx is:  128  and accent_list is:  ['England English']
# idx is:  129  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  130  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  131  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  132  and accent_list is:  ['England English']
# idx is:  133  and accent_list is:  ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)']
# idx is:  134  and accent_list is:  ['Scottish English']
# idx is:  135  and accent_list is:  ['United States English']
# idx is:  136  and accent_list is:  ['Hispanic/Latino']
# idx is:  137  and accent_list is:  ['Australian English']
# idx is:  138  and accent_list is:  ['England English']
# idx is:  139  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)', 'England English']
# idx is:  139  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)', 'England English']
# idx is:  140  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  141  and accent_list is:  ['United States English']
# idx is:  142  and accent_list is:  ['England English']
# idx is:  143  and accent_list is:  ['Hong Kong English']
# idx is:  144  and accent_list is:  ['England English']
# idx is:  145  and accent_list is:  ['United States English']
# idx is:  146  and accent_list is:  ['Australian English']
# idx is:  147  and accent_list is:  ['United States English']
# idx is:  148  and accent_list is:  ['United States English']
# idx is:  149  and accent_list is:  ['Canadian English']
# idx is:  150  and accent_list is:  ['United States English']
# idx is:  151  and accent_list is:  ['United States English']
# idx is:  152  and accent_list is:  ['United States English']
# idx is:  153  and accent_list is:  ['United States English']
# idx is:  154  and accent_list is:  ['England English']
# idx is:  155  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  156  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  157  and accent_list is:  ['United States English']
# idx is:  158  and accent_list is:  ['England English']
# idx is:  159  and accent_list is:  ['United States English']
# idx is:  160  and accent_list is:  ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)']
# idx is:  161  and accent_list is:  ['United States English']
# idx is:  162  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  163  and accent_list is:  ['United States English']
# idx is:  164  and accent_list is:  ['Canadian English']
# idx is:  165  and accent_list is:  ['United States English']
# idx is:  166  and accent_list is:  ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)']
# idx is:  167  and accent_list is:  ['Non-native']
# idx is:  168  and accent_list is:  ['United States English']
# idx is:  169  and accent_list is:  ['United States English']
# idx is:  170  and accent_list is:  ['Georgian English']
# idx is:  171  and accent_list is:  ['Canadian English']
# idx is:  172  and accent_list is:  ['Australian English']
# idx is:  173  and accent_list is:  ['United States English']
# idx is:  174  and accent_list is:  ['England English']
# idx is:  175  and accent_list is:  ['United States English']
# idx is:  176  and accent_list is:  ['United States English']
# idx is:  177  and accent_list is:  ['United States English']
# idx is:  178  and accent_list is:  ['England English']
# idx is:  179  and accent_list is:  ['United States English']
# idx is:  180  and accent_list is:  ['United States English']
# idx is:  181  and accent_list is:  ['Non native']
# idx is:  182  and accent_list is:  ['United States English']
# idx is:  183  and accent_list is:  ['United States English']
# idx is:  184  and accent_list is:  ['Scottish English']
# idx is:  185  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  186  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  187  and accent_list is:  ['Australian English']
# idx is:  188  and accent_list is:  ['England English']
# idx is:  189  and accent_list is:  ['United States English']
# idx is:  190  and accent_list is:  ['United States English']
# idx is:  191  and accent_list is:  ['United States English', 'Canadian English', 'Indo-Canadian English']
# idx is:  191  and accent_list is:  ['United States English', 'Canadian English', 'Indo-Canadian English']
# idx is:  191  and accent_list is:  ['United States English', 'Canadian English', 'Indo-Canadian English']
# idx is:  192  and accent_list is:  ['England English']
# idx is:  193  and accent_list is:  ['United States English']
# idx is:  194  and accent_list is:  ['Australian English']
# idx is:  195  and accent_list is:  ['Canadian English']
# idx is:  196  and accent_list is:  ['United States English']
# idx is:  197  and accent_list is:  ['United States English']
# idx is:  198  and accent_list is:  ['England English']
# idx is:  199  and accent_list is:  ['New Zealand English']
# idx is:  200  and accent_list is:  ['England English']
# idx is:  201  and accent_list is:  ['French']
# idx is:  202  and accent_list is:  ['England English']
# idx is:  203  and accent_list is:  ['England English']
# idx is:  204  and accent_list is:  ['England English']
# idx is:  205  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  206  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  207  and accent_list is:  ['United States English']
# idx is:  208  and accent_list is:  ['United States English']
# idx is:  209  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  210  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  211  and accent_list is:  ['United States English']
# idx is:  212  and accent_list is:  ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)']
# idx is:  213  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  214  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  215  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  216  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  217  and accent_list is:  ['United States English']
# idx is:  218  and accent_list is:  ['United States English']
# idx is:  219  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  220  and accent_list is:  ['United States English']
# idx is:  221  and accent_list is:  ['United States English']
# idx is:  222  and accent_list is:  ['Australian English']
# idx is:  223  and accent_list is:  ['United States English']
# idx is:  224  and accent_list is:  ['United States English']
# idx is:  225  and accent_list is:  ['England English']
# idx is:  226  and accent_list is:  ['England English']
# idx is:  227  and accent_list is:  ['United States English']
# idx is:  228  and accent_list is:  ['England English']
# idx is:  229  and accent_list is:  ['United States English']
# idx is:  230  and accent_list is:  ['Canadian English']
# idx is:  231  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  232  and accent_list is:  ['United States English']
# idx is:  233  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  234  and accent_list is:  ['Australian English']
# idx is:  235  and accent_list is:  ['United States English']
# idx is:  236  and accent_list is:  ['United States English']
# idx is:  237  and accent_list is:  ['United States English']
# idx is:  238  and accent_list is:  ['Canadian English']
# idx is:  239  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  240  and accent_list is:  ['Hong Kong English']
# idx is:  241  and accent_list is:  ['United States English']
# idx is:  242  and accent_list is:  ['New Zealand English']
# idx is:  243  and accent_list is:  ['United States English']
# idx is:  244  and accent_list is:  ['United States English']
# idx is:  245  and accent_list is:  ['United States English']
# idx is:  246  and accent_list is:  ['United States English']
# idx is:  247  and accent_list is:  ['United States English']
# idx is:  248  and accent_list is:  ['Malaysian English']
# idx is:  249  and accent_list is:  ['United States English']
# idx is:  250  and accent_list is:  ['United States English']
# idx is:  251  and accent_list is:  ['United States English']
# idx is:  252  and accent_list is:  ['England English']
# idx is:  253  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  254  and accent_list is:  ['United States English']
# idx is:  255  and accent_list is:  ['United States English']
# idx is:  256  and accent_list is:  ['United States English']
# idx is:  257  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  258  and accent_list is:  ['United States English']
# idx is:  259  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  260  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  261  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  262  and accent_list is:  ['Singaporean English']
# idx is:  263  and accent_list is:  ['United States English']
# idx is:  264  and accent_list is:  ['Canadian English']
# idx is:  265  and accent_list is:  ['Canadian English']
# idx is:  266  and accent_list is:  ['United States English', 'California']
# idx is:  266  and accent_list is:  ['United States English', 'California']
# idx is:  267  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  268  and accent_list is:  ['United States English']
# idx is:  269  and accent_list is:  ['United States English']
# idx is:  270  and accent_list is:  ['United States English']
# idx is:  271  and accent_list is:  ['United States English']
# idx is:  272  and accent_list is:  ['United States English']
# idx is:  273  and accent_list is:  ['United States English']
# idx is:  274  and accent_list is:  ['Hong Kong English']
# idx is:  275  and accent_list is:  ['United States English']
# idx is:  276  and accent_list is:  ['United States English']
# idx is:  277  and accent_list is:  ['Hong Kong English']
# idx is:  278  and accent_list is:  ['United States English']
# idx is:  279  and accent_list is:  ['Canadian English']
# idx is:  280  and accent_list is:  ['Australian English']
# idx is:  281  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  282  and accent_list is:  ['England English']
# idx is:  283  and accent_list is:  ['United States English']
# idx is:  284  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  285  and accent_list is:  ['Malaysian English']
# idx is:  286  and accent_list is:  ['England English']
# idx is:  287  and accent_list is:  ['United States English']
# idx is:  288  and accent_list is:  ['United States English']
# idx is:  289  and accent_list is:  ['United States English']
# idx is:  290  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  291  and accent_list is:  ['Irish English']
# idx is:  292  and accent_list is:  ['Canadian English']
# idx is:  293  and accent_list is:  ['United States English']
# idx is:  294  and accent_list is:  ['New Zealand English']
# idx is:  295  and accent_list is:  ['United States English']
# idx is:  296  and accent_list is:  ['United States English']
# idx is:  297  and accent_list is:  ['United States English']
# idx is:  298  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  299  and accent_list is:  ['England English']
# idx is:  300  and accent_list is:  ['United States English']
# idx is:  301  and accent_list is:  ['United States English']
# idx is:  302  and accent_list is:  ['United States English']
# idx is:  303  and accent_list is:  ['Chinese']
# idx is:  304  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  305  and accent_list is:  ['United States English']
# idx is:  306  and accent_list is:  ['United States English']
# idx is:  307  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  308  and accent_list is:  ['England English']
# idx is:  309  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  310  and accent_list is:  ['United States English']
# idx is:  311  and accent_list is:  ['United States English']
# idx is:  312  and accent_list is:  ['United States English']
# idx is:  313  and accent_list is:  ['England English']
# idx is:  314  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  315  and accent_list is:  ['England English']
# idx is:  316  and accent_list is:  ['United States English']
# idx is:  317  and accent_list is:  ['England English']
# idx is:  318  and accent_list is:  ['United States English']
# idx is:  319  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  320  and accent_list is:  ['United States English']
# idx is:  321  and accent_list is:  ['United States English']
# idx is:  322  and accent_list is:  ['Malaysian English']
# idx is:  323  and accent_list is:  ['England English', 'Midlands English']
# idx is:  323  and accent_list is:  ['England English', 'Midlands English']
# idx is:  324  and accent_list is:  ['England English']
# idx is:  325  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  326  and accent_list is:  ['England English']
# idx is:  327  and accent_list is:  ['England English']
# idx is:  328  and accent_list is:  ['Hong Kong English']
# idx is:  329  and accent_list is:  ['Canadian English']
# idx is:  330  and accent_list is:  ['United States English']
# idx is:  331  and accent_list is:  ['United States English']
# idx is:  332  and accent_list is:  ['United States English']
# idx is:  333  and accent_list is:  ['England English']
# idx is:  334  and accent_list is:  ['United States English']
# idx is:  335  and accent_list is:  ['England English']
# idx is:  336  and accent_list is:  ['United States English']
# idx is:  337  and accent_list is:  ['United States English']
# idx is:  338  and accent_list is:  ['Canadian English']
# idx is:  339  and accent_list is:  ['United States English']
# idx is:  340  and accent_list is:  ['England English']
# idx is:  341  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  342  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  343  and accent_list is:  ['United States English']
# idx is:  344  and accent_list is:  ['United States English']
# idx is:  345  and accent_list is:  ['United States English']
# idx is:  346  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  347  and accent_list is:  ['United States English']
# idx is:  348  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  349  and accent_list is:  ['United States English']
# idx is:  350  and accent_list is:  ['England English']
# idx is:  351  and accent_list is:  ['England English']
# idx is:  352  and accent_list is:  ['United States English']
# idx is:  353  and accent_list is:  ['Hong Kong English']
# idx is:  354  and accent_list is:  ['United States English']
# idx is:  355  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  356  and accent_list is:  ['Australian English']
# idx is:  357  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  358  and accent_list is:  ['United States English']
# idx is:  359  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  360  and accent_list is:  ['United States English']
# idx is:  361  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  362  and accent_list is:  ['United States English']
# idx is:  363  and accent_list is:  ['United States English']
# idx is:  364  and accent_list is:  ['United States English']
# idx is:  365  and accent_list is:  ['french accent']
# idx is:  366  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  367  and accent_list is:  ['United States English']
# idx is:  368  and accent_list is:  ['England English']
# idx is:  369  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  370  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  371  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  372  and accent_list is:  ['United States English']
# idx is:  373  and accent_list is:  ['United States English']
# idx is:  374  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  375  and accent_list is:  ['United States English']
# idx is:  376  and accent_list is:  ['Singaporean English']
# idx is:  377  and accent_list is:  ['England English']
# idx is:  378  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  379  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  380  and accent_list is:  ['United States English']
# idx is:  381  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  382  and accent_list is:  ['United States English']
# idx is:  383  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  384  and accent_list is:  ['United States English']
# idx is:  385  and accent_list is:  ['United States English']
# idx is:  386  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  387  and accent_list is:  ['Scottish English']
# idx is:  388  and accent_list is:  ['United States English']
# idx is:  389  and accent_list is:  ['United States English']
# idx is:  390  and accent_list is:  ['England English']
# idx is:  391  and accent_list is:  ['United States English']
# idx is:  392  and accent_list is:  ['United States English']
# idx is:  393  and accent_list is:  ['England English']
# idx is:  394  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  395  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  396  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  397  and accent_list is:  ['Irish English']
# idx is:  398  and accent_list is:  ['England English']
# idx is:  399  and accent_list is:  ['United States English']
# idx is:  400  and accent_list is:  ['England English']
# idx is:  401  and accent_list is:  ['United States English']
# idx is:  402  and accent_list is:  ['United States English']
# idx is:  403  and accent_list is:  ['United States English']
# idx is:  404  and accent_list is:  ['England English']
# idx is:  405  and accent_list is:  ['Hong Kong English']
# idx is:  406  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)', 'United States English']
# idx is:  406  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)', 'United States English']
# idx is:  407  and accent_list is:  ['United States English']
# idx is:  408  and accent_list is:  ['Canadian English']
# idx is:  409  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  410  and accent_list is:  ['England English']
# idx is:  411  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  412  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  413  and accent_list is:  ['England English']
# idx is:  414  and accent_list is:  ['United States English']
# idx is:  415  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  416  and accent_list is:  ['United States English']
# idx is:  417  and accent_list is:  ['New Zealand English']
# idx is:  418  and accent_list is:  ['England English']
# idx is:  419  and accent_list is:  ['United States English', 'England English']
# idx is:  419  and accent_list is:  ['United States English', 'England English']
# idx is:  420  and accent_list is:  ['United States English']
# idx is:  421  and accent_list is:  ['Hong Kong English']
# idx is:  422  and accent_list is:  ['United States English']
# idx is:  423  and accent_list is:  ['United States English']
# idx is:  424  and accent_list is:  ['United States English']
# idx is:  425  and accent_list is:  ['northern cali']
# idx is:  426  and accent_list is:  ['United States English']
# idx is:  427  and accent_list is:  ['United States English']
# idx is:  428  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  429  and accent_list is:  ['nigeria english']
# idx is:  430  and accent_list is:  ['United States English']
# idx is:  431  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  432  and accent_list is:  ['English County Durham']
# idx is:  433  and accent_list is:  ['England English']
# idx is:  434  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  435  and accent_list is:  ['United States English']
# idx is:  436  and accent_list is:  ['Canadian English']
# idx is:  437  and accent_list is:  ['England English']
# idx is:  438  and accent_list is:  ['England English']
# idx is:  439  and accent_list is:  ['United States English']
# idx is:  440  and accent_list is:  ['United States English']
# idx is:  441  and accent_list is:  ['United States English']
# idx is:  442  and accent_list is:  ['United States English']
# idx is:  443  and accent_list is:  ['United States English']
# idx is:  444  and accent_list is:  ['United States English']
# idx is:  445  and accent_list is:  ['United States English']
# idx is:  446  and accent_list is:  ['Malaysian English']
# idx is:  447  and accent_list is:  ['Australian English']
# idx is:  448  and accent_list is:  ['United States English']
# idx is:  449  and accent_list is:  ['United States English']
# idx is:  450  and accent_list is:  ['Australian English']
# idx is:  451  and accent_list is:  ['England English']
# idx is:  452  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  453  and accent_list is:  ['United States English']
# idx is:  454  and accent_list is:  ['United States English']
# idx is:  455  and accent_list is:  ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)']
# idx is:  456  and accent_list is:  ['United States English']
# idx is:  457  and accent_list is:  ['Выраженный украинский акцент']
# idx is:  458  and accent_list is:  ['Irish English']
# idx is:  459  and accent_list is:  ['Hong Kong English']
# idx is:  460  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  461  and accent_list is:  ['Catalan']
# idx is:  462  and accent_list is:  ['England English']
# idx is:  463  and accent_list is:  ['United States English']
# idx is:  464  and accent_list is:  ['United States English']
# idx is:  465  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  466  and accent_list is:  ['Polish English']
# idx is:  467  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  468  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  469  and accent_list is:  ['United States English']
# idx is:  470  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  471  and accent_list is:  ['Australian English']
# idx is:  472  and accent_list is:  ['Canadian English']
# idx is:  473  and accent_list is:  ['European English', 'French', 'Romanian']
# idx is:  473  and accent_list is:  ['European English', 'French', 'Romanian']
# idx is:  473  and accent_list is:  ['European English', 'French', 'Romanian']
# idx is:  474  and accent_list is:  ['United States English']
# idx is:  475  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  476  and accent_list is:  ['United States English']
# idx is:  477  and accent_list is:  ['England English']
# idx is:  478  and accent_list is:  ['Canadian English']
# idx is:  479  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  480  and accent_list is:  ['England English']
# idx is:  481  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  482  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  483  and accent_list is:  ['United States English']
# idx is:  484  and accent_list is:  ['United States English']
# idx is:  485  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  486  and accent_list is:  ['Hong Kong English']
# idx is:  487  and accent_list is:  ['England English']
# idx is:  488  and accent_list is:  ['United States English']
# idx is:  489  and accent_list is:  ['United States English']
# idx is:  490  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  491  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  492  and accent_list is:  ['United States English']
# idx is:  493  and accent_list is:  ['United States English']
# idx is:  494  and accent_list is:  ['Welsh English']
# idx is:  495  and accent_list is:  ['England English']
# idx is:  496  and accent_list is:  ['United States English']
# idx is:  497  and accent_list is:  ['England English']
# idx is:  498  and accent_list is:  ['United States English']
# idx is:  499  and accent_list is:  ['United States English']
# idx is:  500  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  501  and accent_list is:  ['England English']
# idx is:  502  and accent_list is:  ['England English']
# idx is:  503  and accent_list is:  ['United States English']
# idx is:  504  and accent_list is:  ['United States English']
# idx is:  505  and accent_list is:  ['United States English']
# idx is:  506  and accent_list is:  ['England English']
# idx is:  507  and accent_list is:  ['United States English']
# idx is:  508  and accent_list is:  ['United States English']
# idx is:  509  and accent_list is:  ['Canadian English']
# idx is:  510  and accent_list is:  ['United States English']
# idx is:  511  and accent_list is:  ['United States English']
# idx is:  512  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  513  and accent_list is:  ['United States English']
# idx is:  514  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  515  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  516  and accent_list is:  ['Hong Kong English']
# idx is:  517  and accent_list is:  ['England English']
# idx is:  518  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  519  and accent_list is:  ['United States English']
# idx is:  520  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  521  and accent_list is:  ['United States English']
# idx is:  522  and accent_list is:  ['England English']
# idx is:  523  and accent_list is:  ['United States English']
# idx is:  524  and accent_list is:  ['United States English']
# idx is:  525  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  526  and accent_list is:  ['United States English']
# idx is:  527  and accent_list is:  ['United States English']
# idx is:  528  and accent_list is:  ['Australian English', 'United States English']
# idx is:  528  and accent_list is:  ['Australian English', 'United States English']
# idx is:  529  and accent_list is:  ['United States English']
# idx is:  530  and accent_list is:  ['Australian English']
# idx is:  531  and accent_list is:  ['United States English']
# idx is:  532  and accent_list is:  ['United States English']
# idx is:  533  and accent_list is:  ['United States English']
# idx is:  534  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  535  and accent_list is:  ['United States English']
# idx is:  536  and accent_list is:  ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)']
# idx is:  537  and accent_list is:  ['United States English']
# idx is:  538  and accent_list is:  ['Australian English']
# idx is:  539  and accent_list is:  ['United States English']
# idx is:  540  and accent_list is:  ['United States English']
# idx is:  541  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  542  and accent_list is:  ['United States English']
# idx is:  543  and accent_list is:  ['England English']
# idx is:  544  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  545  and accent_list is:  ['Latino']
# idx is:  546  and accent_list is:  ['United States English']
# idx is:  547  and accent_list is:  ['United States English']
# idx is:  548  and accent_list is:  ['United States English']
# idx is:  549  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  550  and accent_list is:  ['United States English']
# idx is:  551  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  552  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  553  and accent_list is:  ['Canadian English']
# idx is:  554  and accent_list is:  ['United States English']
# idx is:  555  and accent_list is:  ['England English']
# idx is:  556  and accent_list is:  ['Irish English']
# idx is:  557  and accent_list is:  ['Canadian English']
# idx is:  558  and accent_list is:  ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)']
# idx is:  559  and accent_list is:  ['United States English']
# idx is:  560  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  561  and accent_list is:  ['United States English']
# idx is:  562  and accent_list is:  ['England English']
# idx is:  563  and accent_list is:  ['England English']
# idx is:  564  and accent_list is:  ['United States English']
# idx is:  565  and accent_list is:  ['United States English']
# idx is:  566  and accent_list is:  ['United States English']
# idx is:  567  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  568  and accent_list is:  ['United States English']
# idx is:  569  and accent_list is:  ['United States English']
# idx is:  570  and accent_list is:  ['Australian English']
# idx is:  571  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  572  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  573  and accent_list is:  ['Canadian English']
# idx is:  574  and accent_list is:  ['Irish English']
# idx is:  575  and accent_list is:  ['United States English']
# idx is:  576  and accent_list is:  ['Singaporean English']
# idx is:  577  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  578  and accent_list is:  ['England English']
# idx is:  579  and accent_list is:  ['United States English']
# idx is:  580  and accent_list is:  ['Canadian English']
# idx is:  581  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  582  and accent_list is:  ['England English']
# idx is:  583  and accent_list is:  ['United States English']
# idx is:  584  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  585  and accent_list is:  ['United States English']
# idx is:  586  and accent_list is:  ['United States English']
# idx is:  587  and accent_list is:  ['United States English']
# idx is:  588  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  589  and accent_list is:  ['United States English']
# idx is:  590  and accent_list is:  ['England English']
# idx is:  591  and accent_list is:  ['United States English']
# idx is:  592  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  593  and accent_list is:  ['United States English']
# idx is:  594  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  595  and accent_list is:  ['United States English']
# idx is:  596  and accent_list is:  ['United States English']
# idx is:  597  and accent_list is:  ['England English']
# idx is:  598  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  599  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  600  and accent_list is:  ['Irish English']
# idx is:  601  and accent_list is:  ['United States English']
# idx is:  602  and accent_list is:  ['England English', 'Hong Kong English']
# idx is:  602  and accent_list is:  ['England English', 'Hong Kong English']
# idx is:  603  and accent_list is:  ['United States English']
# idx is:  604  and accent_list is:  ['England English']
# idx is:  605  and accent_list is:  ['United States English']
# idx is:  606  and accent_list is:  ['England English']
# idx is:  607  and accent_list is:  ['England English']
# idx is:  608  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  609  and accent_list is:  ['United States English']
# idx is:  610  and accent_list is:  ['England English']
# idx is:  611  and accent_list is:  ['New Zealand English']
# idx is:  612  and accent_list is:  ['British']
# idx is:  613  and accent_list is:  ['Hong Kong English']
# idx is:  614  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  615  and accent_list is:  ['Filipino']
# idx is:  616  and accent_list is:  ['United States English']
# idx is:  617  and accent_list is:  ['United States English']
# idx is:  618  and accent_list is:  ['United States English']
# idx is:  619  and accent_list is:  ['United States English']
# idx is:  620  and accent_list is:  ['United States English']
# idx is:  621  and accent_list is:  ['England English']
# idx is:  622  and accent_list is:  ['England English']
# idx is:  623  and accent_list is:  ['United States English']
# idx is:  624  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  625  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  626  and accent_list is:  ['England English']
# idx is:  627  and accent_list is:  ['United States English']
# idx is:  628  and accent_list is:  ['United States English']
# idx is:  629  and accent_list is:  ['England English']
# idx is:  630  and accent_list is:  ['England English']
# idx is:  631  and accent_list is:  ['New Zealand English']
# idx is:  632  and accent_list is:  ['United States English']
# idx is:  633  and accent_list is:  ['United States English']
# idx is:  634  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  635  and accent_list is:  ['England English']
# idx is:  636  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  637  and accent_list is:  ['Australian English']
# idx is:  638  and accent_list is:  ['United States English']
# idx is:  639  and accent_list is:  ['United States English']
# idx is:  640  and accent_list is:  ['United States English']
# idx is:  641  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  642  and accent_list is:  ['United States English']
# idx is:  643  and accent_list is:  ['United States English']
# idx is:  644  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  645  and accent_list is:  ['England English']
# idx is:  646  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  647  and accent_list is:  ['Scottish English']
# idx is:  648  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  649  and accent_list is:  ['United States English']
# idx is:  650  and accent_list is:  ['German English']
# idx is:  651  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  652  and accent_list is:  ['United States English']
# idx is:  653  and accent_list is:  ['United States English']
# idx is:  654  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  655  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  656  and accent_list is:  ['England English']
# idx is:  657  and accent_list is:  ['Canadian English']
# idx is:  658  and accent_list is:  ['England English']
# idx is:  659  and accent_list is:  ['United States English']
# idx is:  660  and accent_list is:  ['England English']
# idx is:  661  and accent_list is:  ['United States English']
# idx is:  662  and accent_list is:  ['United States English']
# idx is:  663  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  664  and accent_list is:  ['United States English']
# idx is:  665  and accent_list is:  ['England English']
# idx is:  666  and accent_list is:  ['United States English']
# idx is:  667  and accent_list is:  ['England English']
# idx is:  668  and accent_list is:  ['United States English']
# idx is:  669  and accent_list is:  ['United States English']
# idx is:  670  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  671  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  672  and accent_list is:  ['United States English']
# idx is:  673  and accent_list is:  ['United States English']
# idx is:  674  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  675  and accent_list is:  ['United States English']
# idx is:  676  and accent_list is:  ['United States English']
# idx is:  677  and accent_list is:  ['United States English']
# idx is:  678  and accent_list is:  ['England English']
# idx is:  679  and accent_list is:  ['United States English']
# idx is:  680  and accent_list is:  ['England English']
# idx is:  681  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  682  and accent_list is:  ['England English']
# idx is:  683  and accent_list is:  ['Nigerian ']
# idx is:  684  and accent_list is:  ['England English']
# idx is:  685  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  686  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  687  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  688  and accent_list is:  ['England English']
# idx is:  689  and accent_list is:  ['Singaporean English']
# idx is:  690  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  691  and accent_list is:  ['Swedish English']
# idx is:  692  and accent_list is:  ['United States English']
# idx is:  693  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  694  and accent_list is:  ['England English']
# idx is:  695  and accent_list is:  ['United States English']
# idx is:  696  and accent_list is:  ['United States English']
# idx is:  697  and accent_list is:  ['United States English']
# idx is:  698  and accent_list is:  ['United States English']
# idx is:  699  and accent_list is:  ['United States English']
# idx is:  700  and accent_list is:  ['United States English']
# idx is:  701  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  702  and accent_list is:  ['England English']
# idx is:  703  and accent_list is:  ['Scottish English']
# ...
# idx is:  14584  and accent_list is:  ['England English']
# idx is:  14585  and accent_list is:  ['United States English']
# idx is:  14586  and accent_list is:  ['United States English']
# idx is:  14587  and accent_list is:  ['Canadian English']
# idx is:  14588  and accent_list is:  ['United States English']
# idx is:  14589  and accent_list is:  ['United States English']
# idx is:  14590  and accent_list is:  ['Australian English']
# idx is:  14591  and accent_list is:  ['United States English']
# idx is:  14592  and accent_list is:  ['United States English']
# idx is:  14593  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  14594  and accent_list is:  ['United States English']
# idx is:  14595  and accent_list is:  ['United States English']
# idx is:  14596  and accent_list is:  ['United States English']
# idx is:  14597  and accent_list is:  ['England English']
# idx is:  14598  and accent_list is:  ['United States English']
# idx is:  14599  and accent_list is:  ['United States English']
# idx is:  14600  and accent_list is:  ['United States English']
# idx is:  14601  and accent_list is:  ['New Zealand English']
# idx is:  14602  and accent_list is:  ['United States English']
# idx is:  14603  and accent_list is:  ['England English']
# idx is:  14604  and accent_list is:  ['United States English']
# idx is:  14605  and accent_list is:  ['United States English']
# idx is:  14606  and accent_list is:  ['England English']
# idx is:  14607  and accent_list is:  ['United States English']
# idx is:  14608  and accent_list is:  ['England English']
# idx is:  14609  and accent_list is:  ['England English']
# idx is:  14610  and accent_list is:  ['Irish English']
# idx is:  14611  and accent_list is:  ['United States English']
# idx is:  14612  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14613  and accent_list is:  ['United States English']
# idx is:  14614  and accent_list is:  ['United States English']
# idx is:  14615  and accent_list is:  ['United States English']
# idx is:  14616  and accent_list is:  ['United States English']
# idx is:  14617  and accent_list is:  ['England English']
# idx is:  14618  and accent_list is:  ['Canadian English']
# idx is:  14619  and accent_list is:  ['United States English']
# idx is:  14620  and accent_list is:  ['Canadian English']
# idx is:  14621  and accent_list is:  ['Southern African (South Africa, Zimbabwe, Namibia)']
# idx is:  14622  and accent_list is:  ['United States English']
# idx is:  14623  and accent_list is:  ['England English']
# idx is:  14624  and accent_list is:  ['New Zealand English']
# idx is:  14625  and accent_list is:  ['England English']
# idx is:  14626  and accent_list is:  ['Canadian English']
# idx is:  14627  and accent_list is:  ['United States English']
# idx is:  14628  and accent_list is:  ['United States English']
# idx is:  14629  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14630  and accent_list is:  ['England English']
# idx is:  14631  and accent_list is:  ['United States English']
# idx is:  14632  and accent_list is:  ['United States English']
# idx is:  14633  and accent_list is:  ['United States English']
# idx is:  14634  and accent_list is:  ['United States English']
# idx is:  14635  and accent_list is:  ['England English']
# idx is:  14636  and accent_list is:  ['Canadian English']
# idx is:  14637  and accent_list is:  ['England English']
# idx is:  14638  and accent_list is:  ['United States English']
# idx is:  14639  and accent_list is:  ['United States English']
# idx is:  14640  and accent_list is:  ['United States English']
# idx is:  14641  and accent_list is:  ['England English']
# idx is:  14642  and accent_list is:  ['Hong Kong English']
# idx is:  14643  and accent_list is:  ['England English']
# idx is:  14644  and accent_list is:  ['United States English']
# idx is:  14645  and accent_list is:  ['Australian English']
# idx is:  14646  and accent_list is:  ['United States English']
# idx is:  14647  and accent_list is:  ['United States English']
# idx is:  14648  and accent_list is:  ['United States English']
# idx is:  14649  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14650  and accent_list is:  ['Canadian English']
# idx is:  14651  and accent_list is:  ['Australian English']
# idx is:  14652  and accent_list is:  ['United States English']
# idx is:  14653  and accent_list is:  ['England English']
# idx is:  14654  and accent_list is:  ['England English']
# idx is:  14655  and accent_list is:  ['United States English']
# idx is:  14656  and accent_list is:  ['England English']
# idx is:  14657  and accent_list is:  ['Australian English']
# idx is:  14658  and accent_list is:  ['England English']
# idx is:  14659  and accent_list is:  ['Canadian English']
# idx is:  14660  and accent_list is:  ['United States English']
# idx is:  14661  and accent_list is:  ['England English']
# idx is:  14662  and accent_list is:  ['United States English']
# idx is:  14663  and accent_list is:  ['New Zealand English']
# idx is:  14664  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14665  and accent_list is:  ['United States English']
# idx is:  14666  and accent_list is:  ['United States English']
# idx is:  14667  and accent_list is:  ['United States English']
# idx is:  14668  and accent_list is:  ['United States English']
# idx is:  14669  and accent_list is:  ['United States English']
# idx is:  14670  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14671  and accent_list is:  ['United States English']
# idx is:  14672  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14673  and accent_list is:  ['Canadian English']
# idx is:  14674  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14675  and accent_list is:  ['Canadian English']
# idx is:  14676  and accent_list is:  ['United States English']
# idx is:  14677  and accent_list is:  ['England English']
# idx is:  14678  and accent_list is:  ['United States English']
# idx is:  14679  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14680  and accent_list is:  ['Canadian English']
# idx is:  14681  and accent_list is:  ['United States English']
# idx is:  14682  and accent_list is:  ['Irish English']
# idx is:  14683  and accent_list is:  ['United States English']
# idx is:  14684  and accent_list is:  ['United States English']
# idx is:  14685  and accent_list is:  ['United States English']
# idx is:  14686  and accent_list is:  ['England English']
# idx is:  14687  and accent_list is:  ['United States English']
# idx is:  14688  and accent_list is:  ['England English']
# idx is:  14689  and accent_list is:  ['England English']
# idx is:  14690  and accent_list is:  ['England English']
# idx is:  14691  and accent_list is:  ['United States English']
# idx is:  14692  and accent_list is:  ['England English']
# idx is:  14693  and accent_list is:  ['United States English']
# idx is:  14694  and accent_list is:  ['United States English']
# idx is:  14695  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14696  and accent_list is:  ['United States English']
# idx is:  14697  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14698  and accent_list is:  ['United States English']
# idx is:  14699  and accent_list is:  ['United States English']
# idx is:  14700  and accent_list is:  ['Australian English']
# idx is:  14701  and accent_list is:  ['United States English']
# idx is:  14702  and accent_list is:  ['England English']
# idx is:  14703  and accent_list is:  ['Australian English']
# idx is:  14704  and accent_list is:  ['United States English']
# idx is:  14705  and accent_list is:  ['Australian English']
# idx is:  14706  and accent_list is:  ['Canadian English']
# idx is:  14707  and accent_list is:  ['England English']
# idx is:  14708  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14709  and accent_list is:  ['Australian English']
# idx is:  14710  and accent_list is:  ['United States English']
# idx is:  14711  and accent_list is:  ['Irish English']
# idx is:  14712  and accent_list is:  ['United States English']
# idx is:  14713  and accent_list is:  ['United States English']
# idx is:  14714  and accent_list is:  ['United States English']
# idx is:  14715  and accent_list is:  ['England English']
# idx is:  14716  and accent_list is:  ['Australian English']
# idx is:  14717  and accent_list is:  ['Australian English']
# idx is:  14718  and accent_list is:  ['United States English']
# idx is:  14719  and accent_list is:  ['United States English']
# idx is:  14720  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14721  and accent_list is:  ['Australian English']
# idx is:  14722  and accent_list is:  ['United States English']
# idx is:  14723  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14724  and accent_list is:  ['United States English']
# idx is:  14725  and accent_list is:  ['England English']
# idx is:  14726  and accent_list is:  ['England English']
# idx is:  14727  and accent_list is:  ['United States English']
# idx is:  14728  and accent_list is:  ['England English']
# idx is:  14729  and accent_list is:  ['United States English']
# idx is:  14730  and accent_list is:  ['New Zealand English']
# idx is:  14731  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14732  and accent_list is:  ['United States English']
# idx is:  14733  and accent_list is:  ['Canadian English']
# idx is:  14734  and accent_list is:  ['United States English']
# idx is:  14735  and accent_list is:  ['United States English']
# idx is:  14736  and accent_list is:  ['England English']
# idx is:  14737  and accent_list is:  ['England English']
# idx is:  14738  and accent_list is:  ['Canadian English']
# idx is:  14739  and accent_list is:  ['United States English']
# idx is:  14740  and accent_list is:  ['Australian English']
# idx is:  14741  and accent_list is:  ['United States English']
# idx is:  14742  and accent_list is:  ['United States English']
# idx is:  14743  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14744  and accent_list is:  ['United States English']
# idx is:  14745  and accent_list is:  ['United States English']
# idx is:  14746  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14747  and accent_list is:  ['United States English']
# idx is:  14748  and accent_list is:  ['Hong Kong English']
# idx is:  14749  and accent_list is:  ['United States English']
# idx is:  14750  and accent_list is:  ['United States English']
# idx is:  14751  and accent_list is:  ['England English']
# idx is:  14752  and accent_list is:  ['United States English']
# idx is:  14753  and accent_list is:  ['Irish English']
# idx is:  14754  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14755  and accent_list is:  ['Australian English']
# idx is:  14756  and accent_list is:  ['United States English']
# idx is:  14757  and accent_list is:  ['Singaporean English']
# idx is:  14758  and accent_list is:  ['Canadian English']
# idx is:  14759  and accent_list is:  ['England English']
# idx is:  14760  and accent_list is:  ['United States English']
# idx is:  14761  and accent_list is:  ['United States English']
# idx is:  14762  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14763  and accent_list is:  ['United States English']
# idx is:  14764  and accent_list is:  ['United States English']
# idx is:  14765  and accent_list is:  ['England English']
# idx is:  14766  and accent_list is:  ['United States English']
# idx is:  14767  and accent_list is:  ['United States English']
# idx is:  14768  and accent_list is:  ['United States English']
# idx is:  14769  and accent_list is:  ['United States English']
# idx is:  14770  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14771  and accent_list is:  ['England English']
# idx is:  14772  and accent_list is:  ['United States English']
# idx is:  14773  and accent_list is:  ['United States English']
# idx is:  14774  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14775  and accent_list is:  ['England English']
# idx is:  14776  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14777  and accent_list is:  ['United States English']
# idx is:  14778  and accent_list is:  ['United States English']
# idx is:  14779  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14780  and accent_list is:  ['United States English']
# idx is:  14781  and accent_list is:  ['England English']
# idx is:  14782  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14783  and accent_list is:  ['Australian English']
# idx is:  14784  and accent_list is:  ['United States English']
# idx is:  14785  and accent_list is:  ['England English']
# idx is:  14786  and accent_list is:  ['United States English']
# idx is:  14787  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14788  and accent_list is:  ['England English', 'New Zealand English']
# idx is:  14788  and accent_list is:  ['England English', 'New Zealand English']
# idx is:  14789  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14790  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14791  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14792  and accent_list is:  ['United States English']
# idx is:  14793  and accent_list is:  ['United States English']
# idx is:  14794  and accent_list is:  ['England English']
# idx is:  14795  and accent_list is:  ['United States English']
# idx is:  14796  and accent_list is:  ['United States English']
# idx is:  14797  and accent_list is:  ['Liverpool English', 'Lancashire English', 'England English']
# idx is:  14797  and accent_list is:  ['Liverpool English', 'Lancashire English', 'England English']
# idx is:  14797  and accent_list is:  ['Liverpool English', 'Lancashire English', 'England English']
# idx is:  14798  and accent_list is:  ['United States English']
# idx is:  14799  and accent_list is:  ['United States English']
# idx is:  14800  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14801  and accent_list is:  ['England English']
# idx is:  14802  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14803  and accent_list is:  ['England English']
# idx is:  14804  and accent_list is:  ['New Zealand English']
# idx is:  14805  and accent_list is:  ['England English']
# idx is:  14806  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14807  and accent_list is:  ['Australian English']
# idx is:  14808  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14809  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14810  and accent_list is:  ['Canadian English']
# idx is:  14811  and accent_list is:  ['India and South Asia (India, Pakistan, Sri Lanka)']
# idx is:  14812  and accent_list is:  ['United States English']
# idx is:  14813  and accent_list is:  ['Northern Irish']
# idx is:  14814  and accent_list is:  ['United States English']
# idx is:  14815  and accent_list is:  ['Scottish English']
# idx is:  14816  and accent_list is:  ['England English']
# idx is:  14817  and accent_list is:  ['Australian English']
# idx is:  14818  and accent_list is:  ['United States English']
# idx is:  14819  and accent_list is:  ['Canadian English']
# idx is:  14820  and accent_list is:  ['United States English']
# idx is:  14821  and accent_list is:  ['German English', 'Non native speaker']
# idx is:  14821  and accent_list is:  ['German English', 'Non native speaker']

# %%
print(type(english_accents_list))
pp.pprint(english_accents_list)
# Out:
# <class 'list'>
# [   ['England English', 'United States English'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English', 'wolof'],
#     ['England English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Latin America', 'United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['Australian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English', 'Colombia'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Non native speaker from France'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['New York City'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Filipino'],
#     ['French'],
#     ['United States English'],
#     ['United States English'],
#     ['Argentinian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Australian English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ["A'lo"],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Finnish'],
#     ['United States English'],
#     [   'United States English',
#         'India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Singaporean English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['Hispanic/Latino'],
#     ['Australian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)', 'England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['Non-native'],
#     ['United States English'],
#     ['United States English'],
#     ['Georgian English'],
#     ['Canadian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Non native'],
#     ['United States English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English', 'Canadian English', 'Indo-Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['England English'],
#     ['French'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Malaysian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Singaporean English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['United States English', 'California'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Malaysian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Chinese'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Malaysian English'],
#     ['England English', 'Midlands English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['Hong Kong English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['french accent'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Irish English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Hong Kong English'],
#     [   'India and South Asia (India, Pakistan, Sri Lanka)',
#         'United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['England English'],
#     ['United States English', 'England English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['northern cali'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['nigeria english'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['English County Durham'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Malaysian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['Выраженный украинский акцент'],
#     ['Irish English'],
#     ['Hong Kong English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Catalan'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Polish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['European English', 'French', 'Romanian'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Welsh English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English', 'United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Latino'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['Irish English'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Irish English'],
#     ['United States English'],
#     ['England English', 'Hong Kong English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['British'],
#     ['Hong Kong English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['German English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Nigerian '],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Singaporean English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Swedish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Irish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['England English', 'United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Spanish bilingual'],
#     ['England English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English', 'Variable'],
#     ['United States English', 'England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English', 'Silicon Valley Native'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     [   'United States English',
#         'United States English. people say I sound like a surffer dude.'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['Malaysian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Australian English'],
#     ['New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['New Zealand English', 'United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['England English', 'United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Filipino'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Malaysian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Liverpudlian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['United States English'],
#     [   'United States English',
#         'Scottish English',
#         'Irish English',
#         'England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English', 'England English', 'Hong Kong English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['England English', 'United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Welsh English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['New Zealand English'],
#     ['England English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     [   'India and South Asia (India, Pakistan, Sri Lanka)',
#         'United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     [   'United States English',
#         'India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Scottish English'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Malaysian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['German English', 'I am German and speak English as learned at school'],
#     ['Australian English'],
#     ['Scottish English'],
#     ['Malaysian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['English with Swiss german accent'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Japanese English'],
#     ['Australian English'],
#     ['Mild Northern England English'],
#     ['England non-native'],
#     ['Canadian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['french accent'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['England English', 'Educated', 'non regional'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ["Israeli's accent "],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English', 'England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Welsh English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Dutch', 'European', 'Adjustable'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['German English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Irish English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['United States English', 'southern', 'formal', 'sultry'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Singaporean English'],
#     ['United States English'],
#     ['Australian English', 'New Zealand English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Welsh English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)', 'Basic'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['East London '],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Malaysian English'],
#     ['Canadian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English', 'England English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     [   'United States English',
#         'Midwest USA speech blended with South Texas USA speech'],
#     ['New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['German Accent'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
# ...
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Filipino'],
#     ['England English'],
#     ['Filipino'],
#     ['England English'],
#     ['New Zealand English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English', 'Midwestern', 'Minnesotan'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Welsh English'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Scottish English'],
#     ['Singaporean English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['Irish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Irish English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Irish English'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English', 'Midwestern', 'Low', 'Demure'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['Scottish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['southern United States', 'United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Scottish English'],
#     ['Australian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['Irish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Irish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['Irish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Irish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English', 'New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Liverpool English', 'Lancashire English', 'England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['New Zealand English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Northern Irish'],
#     ['United States English'],
#     ['Scottish English'],
#     ['England English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['German English', 'Non native speaker']]

# %% [markdown]
# ---
# <a id='Descriptors'></a>
# ## Add descriptors to each accent
#
# In this section, I apply a set of categories to the accent data.
#
# **I use a rule-based approach for reproduceability.**
# This could have been done in a spreadsheet, but I'm working in Python so I chose to do it that way.
# This also makes it easier for others applying this work to other languages or to other versions of the dataset.

# %% [markdown]
# ### Expand accents that have multiple descriptors in their .name element
#
# Here, we "break apart" accents that have multiple descriptors in the .name element into **multiple** accents. This is done _programmatically_ to aid in reproduceability.
#
# Some examples of this that I found during analysis were;
#
# * 8233 - 'south German / Swiss accent' - needs to be separated into 'South German' and 'Swiss accent'
# * 6967 - 'slight Brooklyn Accent' - needs to be separated into "slight" and 'Brooklyn' - as a strength indicator
# * 10142 - 'minor French Accent' - needs to be separated into "minor" as an accent strength indicator, and 'French'
# * 9902 - 'little Latino' - needs to be separated into "little" as an accent strength indicator, and "Latino"
# * 3422 - 'i have some pronunciation issues because of oral surgery and a hidden southern accent' - needs to be separated into 'hidden southern accent' and 'changes due to Oral surgery'
# * 9337 - 'heavy Cantonese' - needs to be separated into accent strength and country
# * 1721 - 'United States English combined with European English' = needs to be separated into two accents
# * 5365 - 'Sydney - middle eastern seaboard Australian' - should be separated into two accents
# * 6615 - 'Spoke Chinese when little' - should be separated into Chinese, and speaking a different language as a child
# * 748 - 'Spanish bilingual' - should be separated into 'Spanish' and 'bilingual ' as an Ln marker.
# * 6942 - 'South London and Essex' - should be separated into 'South London' and 'Essex'
# * 12055 - 'Some time spent in Scotland' - should be separated into 'Scottish English' and into an Ln marker of "time spent in regional location"
# * 773 - 'Silicon Valley Native' - should be separated into 'Silicon Valley' and "native" marker
# * 3033 - "Porto des dels 3 anys aprenent anglès a l'escola i actualment m'estic preparant per a l'examen del B2." - this should be split into French, and academic register / L2 status
# * 4322 - 'Polish. Have lived in nine states.' - should be separated into Polish and "lived in nine states" as a regional variance indicator or mixed accent indicator
# * 5046 - 'Pittsburgh PA' - should be separated into Pittsburgh - city descriptor - and Pennsylvania as a regional descriptor.
# * 58 - 'Non native speaker from France' - should be separated into 'French' and 'Non native speaker'
# * 1054 - 'Mild Northern England English' - should be separated into 'Northern England' and 'mild' for the strength of accent
# * 11587 - 'Midwestern States (Michigan)' - should be separated into Midwestern and Michigan
# * 1317 - 'Midwest USA speech blended with South Texas USA speech' - should be separated into Midwest and South Texas
# * 1491 - 'Midwest US... With some Canadian slang. ' - should be separated into Midwest and Canadian Slang as register
# * 'International Indian Accent' - should be separated into "Indian" and into "International"
# * 2703 - 'Indian with a tinge of an RP accent' - should be separated into "Indian" and "Received Pronunciation" as well as an accent strength marker
# * 1011 - 'I am German and speak English as learned at school' - should be separated into "German" and a register marker "as learned at school"
# * 4839 - 'French mid level' - should be separated into 'French' and 'mid-level' as a fluency marker
# * 1055 - 'England non-native' - should be separated into 'England' and 'Non-native' as a fluency marker
# * 5305 - 'Educated Australian Accent' - should be separated into 'Australian' and 'Educated' as a register marker
# * 12958 - 'CARIBBEAN AND BRITISH MIXED WITH SOME NEW YORK ACCENTS' - should be separated into three accents
# * 1577 - 'British English with a little bit of Russian' - should be separated into two accents. It's also an accent strength marker.
# * 7271 - 'A variety of Texan English with some German influence that has undergone the cot-caught merger' - should be split into Texan, German influence, and a phonetic descriptor
# * 6616 - '90% Pennsylvanian accent' - should be separated into Pennsylvanian and an accent strength marker
# * 4319 - '4 years in Spain and Germany' - should be separated into French, German and a time or exposure marker
# * 6617 - '10% Chinese accent' - should be separated into Chinese and an accent strength marker

# %% [markdown]
# ### Modify the accent list to expand descriptors while preserving accent co-references
#
# Some of the given accent descriptors contain multiple descriptors in one string. Here, I expand them while maintain co-references.
#
# For example:
#
# * `slight Brooklyn accent`  - contains both a City-based descriptor and an accent strength descriptor.
# * `United States English combined with European English` - contains both a national descriptor and a supranational descriptor.
#
#
#
# It's easier to do this before we create Accent and AccentDescriptor objects.

# %%
# helper function for the below 

def update_list_coreference(list_to_be_updated, old_entry, new_entry):
    # the accent list is a list of lists so we need to iterate through each one to find the element to update. 
    
    
    for accent_list in list_to_be_updated:
        
        for accent in accent_list:    
            if accent == old_entry:

                accent_list.remove(old_entry)
                
                for entry in new_entry: # there may be more than one
                    accent_list.append(entry)
    
    return(list_to_be_updated)

# %%
#'south German / Swiss accent' - needs to be separated into 'South German' and 'Swiss'
english_accents_list = update_list_coreference(english_accents_list, 
                                               'south German / Swiss accent', 
                                               ['South German', 'Swiss'])

# 'slight Brooklyn Accent' - needs to be separated into "slight" and 'Brooklyn' - as a strength indicator 
english_accents_list = update_list_coreference(english_accents_list, 
                                               'slight Brooklyn Accent', 
                                               ['Brooklyn Accent', 'slight'])

# 'minor French Accent' - needs to be separated into "minor" as an accent strength indicator, and 'French'
english_accents_list = update_list_coreference(english_accents_list, 
                                               'minor French Accent', 
                                               ['French Accent', 'minor'])

# 'little Latino' - needs to be separated into "Latino" as an accent and 'little' as an accent strength indicator
english_accents_list = update_list_coreference(english_accents_list, 
                                               'little Latino', 
                                               ['Latino', 'little'])
                              
# 'heavy Cantonese' - needs to be separated into accent strength and country   
english_accents_list = update_list_coreference(english_accents_list, 
                                               'heavy Cantonese', 
                                               ['Cantonese', 'heavy'])

# 'United States English combined with European English' - needs to be separated into two accents
english_accents_list = update_list_coreference(english_accents_list, 
                                               'United States English combined with European English', 
                                               ['United States English', 'European English'])

# 'United States English combined with European English' - needs to be separated into two accents
english_accents_list = update_list_coreference(english_accents_list, 
                                               'United States English combined with European English', 
                                               ['United States English', 'European English'])
                                               
# 'Sydney - middle eastern seaboard Australian' - should be separated into two accent
english_accents_list = update_list_coreference(english_accents_list, 
                                               'Sydney - middle eastern seaboard Australian', 
                                               ['Sydney', 'Middle eastern seaboard Australian'])
    
    
# 'Spoke Chinese when little' - should be separated into Chinese, and speaking a different language as a child
english_accents_list = update_list_coreference(english_accents_list, 
                                               'Spoke Chinese when little', 
                                               ['Chinese', 'Spoke language when a child'])    
    
    
    
# 'Spanish bilingual' - should be separated into 'Spanish' and 'bilingual ' as an Ln marker. 
english_accents_list = update_list_coreference(english_accents_list, 
                                               'Spanish bilingual', 
                                               ['Spanish', 'Bilingual']) 










pp.pprint(english_accents_list)
# Out:
# [   ['England English', 'United States English'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English', 'wolof'],
#     ['England English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Latin America', 'United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['Australian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English', 'Colombia'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Non native speaker from France'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['New York City'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Filipino'],
#     ['French'],
#     ['United States English'],
#     ['United States English'],
#     ['Argentinian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Australian English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ["A'lo"],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Finnish'],
#     ['United States English'],
#     [   'United States English',
#         'India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Singaporean English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['Hispanic/Latino'],
#     ['Australian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)', 'England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['Non-native'],
#     ['United States English'],
#     ['United States English'],
#     ['Georgian English'],
#     ['Canadian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Non native'],
#     ['United States English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English', 'Canadian English', 'Indo-Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['England English'],
#     ['French'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Malaysian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Singaporean English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['United States English', 'California'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Malaysian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Chinese'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Malaysian English'],
#     ['England English', 'Midlands English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['Hong Kong English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['french accent'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Irish English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Hong Kong English'],
#     [   'India and South Asia (India, Pakistan, Sri Lanka)',
#         'United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['England English'],
#     ['United States English', 'England English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['northern cali'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['nigeria english'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['English County Durham'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Malaysian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['Выраженный украинский акцент'],
#     ['Irish English'],
#     ['Hong Kong English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Catalan'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Polish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['European English', 'French', 'Romanian'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Welsh English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English', 'United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Latino'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['Irish English'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Irish English'],
#     ['United States English'],
#     ['England English', 'Hong Kong English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['British'],
#     ['Hong Kong English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['German English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Nigerian '],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Singaporean English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Swedish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Irish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['England English', 'United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Spanish bilingual'],
#     ['England English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English', 'Variable'],
#     ['United States English', 'England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English', 'Silicon Valley Native'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     [   'United States English',
#         'United States English. people say I sound like a surffer dude.'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['Malaysian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Australian English'],
#     ['New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['New Zealand English', 'United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['England English', 'United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Filipino'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Malaysian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Liverpudlian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['United States English'],
#     ['United States English'],
#     [   'United States English',
#         'Scottish English',
#         'Irish English',
#         'England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English', 'England English', 'Hong Kong English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['England English', 'United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Welsh English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['New Zealand English'],
#     ['England English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     [   'India and South Asia (India, Pakistan, Sri Lanka)',
#         'United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     [   'United States English',
#         'India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Scottish English'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Malaysian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['German English', 'I am German and speak English as learned at school'],
#     ['Australian English'],
#     ['Scottish English'],
#     ['Malaysian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['English with Swiss german accent'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Japanese English'],
#     ['Australian English'],
#     ['Mild Northern England English'],
#     ['England non-native'],
#     ['Canadian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['french accent'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['England English', 'Educated', 'non regional'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ["Israeli's accent "],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English', 'England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Welsh English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Dutch', 'European', 'Adjustable'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['German English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Irish English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['United States English', 'southern', 'formal', 'sultry'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Singaporean English'],
#     ['United States English'],
#     ['Australian English', 'New Zealand English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Welsh English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)', 'Basic'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['East London '],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Malaysian English'],
#     ['Canadian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English', 'England English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     [   'United States English',
#         'Midwest USA speech blended with South Texas USA speech'],
#     ['New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['German Accent'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
# ...
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Filipino'],
#     ['England English'],
#     ['Filipino'],
#     ['England English'],
#     ['New Zealand English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English', 'Midwestern', 'Minnesotan'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Welsh English'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Scottish English'],
#     ['Singaporean English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['Irish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['Irish English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['Filipino'],
#     ['United States English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Irish English'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Irish English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English', 'Midwestern', 'Low', 'Demure'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['Scottish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['southern United States', 'United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Scottish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Scottish English'],
#     ['Australian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['Scottish English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['Irish English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['Southern African (South Africa, Zimbabwe, Namibia)'],
#     ['United States English'],
#     ['England English'],
#     ['New Zealand English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Hong Kong English'],
#     ['England English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Irish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Australian English'],
#     ['Canadian English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['Irish English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['Australian English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['England English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['Australian English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Hong Kong English'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['Irish English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['Singaporean English'],
#     ['Canadian English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English', 'New Zealand English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['United States English'],
#     ['England English'],
#     ['United States English'],
#     ['United States English'],
#     ['Liverpool English', 'Lancashire English', 'England English'],
#     ['United States English'],
#     ['United States English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['England English'],
#     ['New Zealand English'],
#     ['England English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Australian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['Canadian English'],
#     ['India and South Asia (India, Pakistan, Sri Lanka)'],
#     ['United States English'],
#     ['Northern Irish'],
#     ['United States English'],
#     ['Scottish English'],
#     ['England English'],
#     ['Australian English'],
#     ['United States English'],
#     ['Canadian English'],
#     ['United States English'],
#     ['German English', 'Non native speaker']]

# %%
# So what we want to do here is put them into another list
# So that we can then order that list 

english_accents = df['accents'].unique()

english_accents_dict = {} 
english_accents_list = []
english_accents_list_by_total =[]

for accent in english_accents:
    accent_total = len(df.loc[df['accents'] == accent])
    english_accents_dict[accent] = accent_total
    
# Dict structures in Python are not sortable
# So we're going to iterate so that we can have a sorted list 

for accent_total in english_accents_dict.items(): 
    english_accents_list.append(accent_total)

#print ('\n')
#print ('breakpoint 1')
#print ('\n')

# print the list 
#print(english_accents_list)
    
# Now, we want to order the list
# But if we use sort(), it will sort by the first element, which is the accent itself
# But we want to sort on the number of occurrences of that accent 

for accents_list in english_accents_list: 
    #print(accents_list)
    reversed = accents_list[::-1] # they're tuples, reverse() won't work
    #print(reversed)
    english_accents_list_by_total.append(reversed)
    
english_accents_list_by_total.sort(reverse=True)
    
#print ('\n')
#print ('breakpoint 2')
#print ('\n')

# print the size of the list     
print('Size of the list is: ')
print(len(english_accents_list_by_total))
print('---')

# print the sorted list
print('Sorted list is: ')
pp.pprint(english_accents_list_by_total)
# Out:
# Size of the list is:
# 227
# ---
# Sorted list is:
# [   (7432, 'United States English'),
#     (2281, 'England English'),
#     (1990, 'India and South Asia (India, Pakistan, Sri Lanka)'),
#     (888, 'Canadian English'),
#     (655, 'Australian English'),
#     (260, 'Southern African (South Africa, Zimbabwe, Namibia)'),
#     (186, 'Irish English'),
#     (166, 'Scottish English'),
#     (157, 'New Zealand English'),
#     (129, 'Hong Kong English'),
#     (124, 'Filipino'),
#     (95, 'Malaysian English'),
#     (75, 'Singaporean English'),
#     (65, 'Welsh English'),
#     (48, 'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)'),
#     (13, 'United States English,England English'),
#     (9, 'England English,United States English'),
#     (6, 'German English'),
#     (5, 'South Atlantic (Falkland Islands, Saint Helena)'),
#     (4, 'Russian'),
#     (4, 'French'),
#     (   3,
#         'United States English,India and South Asia (India, Pakistan, Sri '
#         'Lanka)'),
#     (3, 'Slavic'),
#     (3, 'Northern Irish'),
#     (   3,
#         'India and South Asia (India, Pakistan, Sri Lanka),United States '
#         'English'),
#     (3, 'India and South Asia (India, Pakistan, Sri Lanka),England English'),
#     (3, 'German'),
#     (2, 'polish'),
#     (2, 'french accent'),
#     (2, 'United States English,Midwestern United States English'),
#     (2, 'United States English,Midwestern'),
#     (   2,
#         'United States English,England English,India and South Asia (India, '
#         'Pakistan, Sri Lanka)'),
#     (2, 'Thai'),
#     (2, 'Latino'),
#     (2, 'Japanese English'),
#     (2, 'German Accent'),
#     (2, 'Eastern European English'),
#     (2, 'Dutch English'),
#     (2, 'Austrian'),
#     (1, 'Выраженный украинский акцент'),
#     (1, 'southern United States,United States English'),
#     (   1,
#         'slighty Southern affected by decades in the Midwest, 4 years in Spain '
#         'and Germany, speak some German, Spanish, Polish. Have lived in nine '
#         'states.'),
#     (1, 'serbian,United States English'),
#     (1, 'polish accent'),
#     (1, 'northern cali'),
#     (1, 'nigeria english'),
#     (1, 'minor french accent'),
#     (1, 'little latino,United States English,second language'),
#     (1, 'french accent,French mid level accent'),
#     (1, 'fluent,ESL,European'),
#     (1, 'england,london,academic'),
#     (1, 'With heavy Cantonese accent'),
#     (1, 'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad),Patois'),
#     (   1,
#         'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad),England '
#         'English,Scottish English,United States English'),
#     (1, 'West Indian'),
#     (1, 'West African '),
#     (1, 'Upper Midwestern,United States English'),
#     (1, 'United States English,wolof'),
#     (1, 'United States English,southern, formal, sultry'),
#     (1, 'United States English,southern United States,New Orleans dialect'),
#     (1, 'United States English,southern United States'),
#     (1, 'United States English,pin/pen merger'),
#     (1, 'United States English,new england/east coast'),
#     (1, 'United States English,midwestern US'),
#     (1, 'United States English,midwest'),
#     (   1,
#         'United States English,little bit classy little bit sassy and add some '
#         'city.....thats me'),
#     (   1,
#         'United States English,i have some pronunciation issues because of '
#         'oral surgery and a hidden southern accent'),
#     (1, 'United States English,Variable'),
#     (   1,
#         'United States English,United States English. people say I sound like '
#         'a surffer dude.'),
#     (1, 'United States English,United States English Pacific Northwest'),
#     (1, 'United States English,Unite States Midwest'),
#     (   1,
#         'United States English,Spoke Chinese when little,90% Pennsylvanian '
#         'accent, 10% Chinese accent'),
#     (1, 'United States English,Southwestern United States English'),
#     (1, 'United States English,Southern Californian'),
#     (   1,
#         'United States English,Southern Appalachian English,Southern United '
#         'States English'),
#     (1, 'United States English,South Texas,Slightly effeminate,Conversational'),
#     (   1,
#         'United States English,Some time spent in Scotland, mostly affecting '
#         'inflection, I think'),
#     (1, 'United States English,Slight lisp'),
#     (1, 'United States English,Silicon Valley Native'),
#     (1, 'United States English,Scottish English,Irish English,England English'),
#     (1, 'United States English,Pittsburgh PA'),
#     (1, 'United States English,Pacific Northwest '),
#     (1, 'United States English,Okie'),
#     (1, 'United States English,Northern,Urban'),
#     (1, 'United States English,Mix of voices'),
#     (1, 'United States English,Midwestern,Minnesotan'),
#     (1, 'United States English,Midwestern,Low,Demure'),
#     (1, 'United States English,Midwestern US English (United States)'),
#     (1, 'United States English,Midwestern States (Michigan)'),
#     (1, 'United States English,Midwest United States'),
#     (   1,
#         'United States English,Midwest USA speech blended with South Texas USA '
#         'speech'),
#     (1, 'United States English,Midwest US... With some Canadian slang. '),
#     (1, 'United States English,Mid-west United States English'),
#     (1, 'United States English,Kenyan English'),
#     (1, 'United States English,Israeli accent'),
#     (1, 'United States English,Hmong-American'),
#     (1, 'United States English,Filipino'),
#     (1, 'United States English,England English,Hong Kong English'),
#     (1, 'United States English,Cool'),
#     (1, 'United States English,Colombia'),
#     (1, 'United States English,Chicano English,"Valley Girl" English'),
#     (1, 'United States English,Chicago '),
#     (1, 'United States English,Canadian English,slight Brooklyn Accent'),
#     (1, 'United States English,Canadian English,Indo-Canadian English'),
#     (1, 'United States English,Canadian English'),
#     (1, 'United States English,Californian Accent'),
#     (1, 'United States English,California'),
#     (   1,
#         'United States English,CARIBBEAN AND BRITISH MIXED WITH SOME NEW YORK '
#         'ACCENTS'),
#     (   1,
#         'United States English,Australian English,England English,New Zealand '
#         'English,India and South Asia (India, Pakistan, Sri '
#         'Lanka),international,Slovak'),
#     (1, 'United States English,Australian English'),
#     (1, 'United States English,American Midwest'),
#     (1, 'United States English combined with European English'),
#     (1, 'Ukrainian'),
#     (1, 'Transnational englishes blend'),
#     (1, 'Swedish accent'),
#     (1, 'Swedish English'),
#     (1, 'Spanish,Foreign,Non-native'),
#     (1, 'Spanish bilingual'),
#     (1, 'Southern Texas Accent,United States English'),
#     (1, 'South African English'),
#     (1, 'Slavic,polish'),
#     (1, 'Slavic,Russian'),
#     (1, 'Slavic,East European,polish'),
#     (1, 'Singaporean English,Malaysian English'),
#     (1, 'Singaporean English,England English'),
#     (1, 'Scottish English,Scottish'),
#     (1, 'Russian,East Ukrainian '),
#     (1, 'Polish English'),
#     (1, 'Not bad'),
#     (1, 'Norwegian'),
#     (1, 'Northumbrian British English'),
#     (1, 'Northern Irish,Norwegian,yorkshire'),
#     (1, 'Non-native,German Accent'),
#     (1, 'Non-native'),
#     (1, 'Non native speaker from France'),
#     (1, 'Non native'),
#     (1, 'Nigerian English'),
#     (1, 'Nigerian '),
#     (1, 'New Zealand English,United States English'),
#     (1, 'New Zealand English,England English'),
#     (1, 'New York City'),
#     (1, 'Mild Northern England English'),
#     (1, 'Midatlantic,England English'),
#     (1, 'Mid-atlantic,England English,United States English'),
#     (   1,
#         'Mid-Atlantic United States English,Philadelphia, Pennsylvania, United '
#         'States English,United States English,Philadelphia Style United States '
#         'English'),
#     (1, 'Malaysian English,Javanese,Indonesian English'),
#     (1, 'Malaysian English,England English'),
#     (1, 'Liverpudlian English'),
#     (1, 'Liverpool English,Lancashire English,England English'),
#     (1, 'Latin English'),
#     (1, 'Latin American accent'),
#     (1, 'Latin America,United States English'),
#     (1, 'Kiwi'),
#     (1, 'Kenyan '),
#     (1, 'Italian'),
#     (1, "Israeli's accent "),
#     (1, 'International English,United States English,Australian English'),
#     (   1,
#         'India and South Asia (India, Pakistan, Sri Lanka),try to maintain '
#         'originality '),
#     (1, 'India and South Asia (India, Pakistan, Sri Lanka),bangladesh'),
#     (   1,
#         'India and South Asia (India, Pakistan, Sri Lanka),International '
#         'Indian Accent'),
#     (   1,
#         'India and South Asia (India, Pakistan, Sri Lanka),Indian with a tinge '
#         'of an RP accent'),
#     (1, 'India and South Asia (India, Pakistan, Sri Lanka),Canadian English'),
#     (1, 'India and South Asia (India, Pakistan, Sri Lanka),Basic'),
#     (1, 'Hong Kong English,Scottish English'),
#     (1, 'Hispanic/Latino'),
#     (1, 'Greek'),
#     (1, 'German,south-west German,South German accent,Alemannic German Accent'),
#     (1, 'German English,Non native speaker'),
#     (1, 'German English,I am German and speak English as learned at school'),
#     (1, 'Georgian English'),
#     (1, 'Finnish'),
#     (1, 'Filipino,United States English'),
#     (1, "European,eastern europe,pronounced r's,heavy consonants "),
#     (1, 'European,German,Foreign,Non-native'),
#     (1, 'European English,French,Romanian'),
#     (1, 'English with Swiss german accent'),
#     (1, 'English north of England '),
#     (1, 'English County Durham'),
#     (1, 'England non-native'),
#     (1, 'England English,yorkshire'),
#     (1, 'England English,southern english,sussex'),
#     (1, 'England English,south German / Swiss accent'),
#     (1, 'England English,Welsh English'),
#     (1, 'England English,Southern England'),
#     (1, 'England English,South London and Essex'),
#     (1, 'England English,South London'),
#     (1, 'England English,Scottish English'),
#     (   1,
#         "England English,Porto des dels 3 anys aprenent anglès a l'escola i "
#         "actualment m'estic preparant per a l'examen del B2."),
#     (1, 'England English,Northern English'),
#     (1, 'England English,Northern England'),
#     (   1,
#         'England English,New Zealand English,Welsh English,Australian '
#         'English,United States English,Mixed-Accent English'),
#     (1, 'England English,New Zealand English'),
#     (1, 'England English,Midlands English'),
#     (1, 'England English,London English'),
#     (1, 'England English,Lancashire, England '),
#     (   1,
#         'England English,India and South Asia (India, Pakistan, Sri '
#         'Lanka),Northern English'),
#     (1, 'England English,Hong Kong English'),
#     (1, 'England English,Educated,non regional'),
#     (1, 'England English,Canadian English'),
#     (1, 'England English,British'),
#     (1, 'Eastern European,Romanian'),
#     (1, 'East London '),
#     (1, 'East Indian'),
#     (1, 'East African Khoja'),
#     (1, 'Dutch,European,Adjustable'),
#     (1, 'Dutch'),
#     (1, 'Colombian Accent'),
#     (1, 'Chinese'),
#     (1, 'Catalan'),
#     (1, 'Canadian English,United States English,England English'),
#     (1, 'Canadian English,United States English'),
#     (1, 'Canadian English,Irish English'),
#     (1, 'British English with a little bit of Russian'),
#     (1, 'British'),
#     (1, 'Bangladeshi,Bangladesh English'),
#     (1, 'Bangladeshi English'),
#     (1, 'Australian English,United States English'),
#     (1, 'Australian English,Sydney - middle eastern seaboard Australian'),
#     (1, 'Australian English,New Zealand English'),
#     (1, 'Australian English,England English,Japanese'),
#     (1, 'Australian English,England English'),
#     (1, 'Australian English,Educated Australian Accent'),
#     (1, 'Argentinian English'),
#     (1, 'Afrikaans English'),
#     (1, "A'lo"),
#     (   1,
#         'A variety of Texan English with some German influence that has '
#         'undergone the cot-caught merger'),
#     (1, '2nd Language ')]

# %%
# build a dict of each unique accent using an Accent object for each object. 

ratio_display = 120 # to stop the browser crashing 

all_accents = {}
i = 0; 

all_accent_lists = df['accents']

for accent_list in all_accent_lists:
    #print (accent_list)
    
    # the accent_list is a string, not a list
    # and we can't just simply split it by a string 
    # because there are entries that may have a comma in the accent description 
    # such as 
    # India and South Asia (India, Pakistan, Sri Lanka)
    # so instead we use a regex that only splits on a comma ','
    # if the comma is not inside open brackets 
    
    # this regex is from 
    # https://stackoverflow.com/questions/26633452/how-to-split-by-commas-that-are-not-within-parentheses
    accent_list=re.split(',\s*(?![^()]*\))', accent_list)
    
    for accent in accent_list: 
        
        i +=1
        match = False 
        count = 0
        
        #if (i%ratio_display ==0): # only show the 100th 
            #print('')
            #print('---')
            #print('now processing: ', accent, ' - ', i)
            #print('---')
        
        # is this accent in our dict - if not, add it in 
        
        for item in all_accents.items() : # Each item should be an Accent object 
            
            # (self, id=0, name="Accent Name", count=0, locale=None, descriptors=None):
            #pp.pprint(item[1].__str__())
            
            #if (i%ratio_display ==0): # only show the 100th 
                #print('item is: ', item)
                #print(type(item))
                #print('now checking match for: item:', item[1], ' and accent: ', accent)
            
            if (item[1].name == accent) : # update the count
                
                #if (i%ratio_display ==0): # only show the 100th 
                    #print('---')
                    #print('match is True')
                    #print('---')
                    
                match = True 
                
                #if (i%ratio_display ==0): # only show the 100th 
                    #print('accent count was: ', item[1].count)
                
                # update the count of the accent 
                item[1].count+=1
                
                #if (i%ratio_display ==0): # only show the 100th 
                    #print('accent count is now: ', item[1].count)
                
                

        # this match loop has to be outside the for: loop above 
        # because if we add items to the dict inside the loop
        # then it will not run - because there are zero items in the dict to begin with 
        
        if (not match) :   
            
            # (self, id=0, name="Accent Name", count=0, locale=None, descriptors=None):
            all_accents[i] = cva.Accent(i, accent, 1, 'en', None, False) 
            
            if (i%ratio_display ==0): # only show the ratio'th element 
                print ('added ', all_accents[i], ' to dict')
# Out:
# added  id is 1920, name is southern United States, count is 1, locale is en, descriptors are None, predetermined is False.  to dict
# added  id is 4320, name is speak some German, count is 1, locale is en, descriptors are None, predetermined is False.  to dict
# added  id is 5760, name is Kiwi, count is 1, locale is en, descriptors are None, predetermined is False.  to dict

# %%
print(len(all_accents))
# Out:
# 224

# %%
for item in all_accents.items(): 
    pp.pprint(item[1].__str__())
# Out:
# ('id is 1, name is England English, count is 2342, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2, name is United States English, count is 7537, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 3, name is Hong Kong English, count is 132, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7, name is wolof, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9, name is Australian English, count is 665, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 11, name is Latin America, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 15, name is Southern African (South Africa, Zimbabwe, Namibia), count '
#  'is 260, locale is en, descriptors are None, predetermined is False.')
# ('id is 18, name is India and South Asia (India, Pakistan, Sri Lanka), count '
#  'is 2009, locale is en, descriptors are None, predetermined is False.')
# ('id is 31, name is Colombia, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 37, name is Canadian English, count is 896, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 58, name is Non native speaker from France, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 69, name is Scottish English, count is 171, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 78, name is New York City, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 85, name is Filipino, count is 126, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 86, name is French, count is 5, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 89, name is Argentinian English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ("id is 103, name is A'lo, count is 1, locale is en, descriptors are None, "
#  'predetermined is False.')
# ('id is 129, name is Finnish, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 133, name is Singaporean English, count is 77, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 139, name is West Indies and Bermuda (Bahamas, Bermuda, Jamaica, '
#  'Trinidad), count is 50, locale is en, descriptors are None, predetermined is '
#  'False.')
# ('id is 142, name is Hispanic/Latino, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 174, name is Non-native, count is 4, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 177, name is Georgian English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 188, name is Non native, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 200, name is Indo-Canadian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 208, name is New Zealand English, count is 163, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 257, name is Malaysian English, count is 98, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 276, name is California, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 301, name is Irish English, count is 188, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 313, name is Chinese, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 334, name is Midlands English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 376, name is french accent, count is 3, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 438, name is northern cali, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 442, name is nigeria english, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 445, name is English County Durham, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 470, name is Выраженный украинский акцент, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 474, name is Catalan, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 479, name is Polish English, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 486, name is European English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 488, name is Romanian, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 509, name is Welsh English, count is 67, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 561, name is Latino, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 629, name is British, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 667, name is German English, count is 8, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 700, name is Nigerian , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 708, name is Swedish English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 748, name is Spanish bilingual, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 760, name is Variable, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 773, name is Silicon Valley Native, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 778, name is United States English. people say I sound like a surffer '
#  'dude., count is 1, locale is en, descriptors are None, predetermined is '
#  'False.')
# ('id is 879, name is Liverpudlian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1011, name is I am German and speak English as learned at school, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1033, name is English with Swiss german accent, count is 1, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 1052, name is Japanese English, count is 2, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 1054, name is Mild Northern England English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1055, name is England non-native, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1076, name is Educated, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1077, name is non regional, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ("id is 1099, name is Israeli's accent , count is 1, locale is en, descriptors "
#  'are None, predetermined is False.')
# ('id is 1133, name is Dutch, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1134, name is European, count is 4, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1135, name is Adjustable, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1177, name is southern, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1178, name is formal, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1179, name is sultry, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1237, name is Basic, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1252, name is East London , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1317, name is Midwest USA speech blended with South Texas USA speech, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1337, name is German Accent, count is 3, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1485, name is Not bad, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1491, name is Midwest US... With some Canadian slang. , count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 1522, name is West Indian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1534, name is Northern, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1535, name is Urban, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1577, name is British English with a little bit of Russian, count is '
#  '1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1707, name is Northern Irish, count is 4, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 1721, name is United States English combined with European English, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1723, name is International English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1902, name is South Atlantic (Falkland Islands, Saint Helena), count '
#  'is 5, locale is en, descriptors are None, predetermined is False.')
# ('id is 1920, name is southern United States, count is 3, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1921, name is Russian, count is 6, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1938, name is pin/pen merger, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 1977, name is Southern Appalachian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1978, name is Southern United States English, count is 1, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 1998, name is United States English Pacific Northwest, count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 2174, name is Southern Texas Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 2191, name is midwestern US, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 2205, name is Midwest United States, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 2446, name is Mix of voices, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 2455, name is Colombian Accent, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2456, name is German, count is 5, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2571, name is Slavic, count is 6, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2630, name is Scottish, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 2685, name is Patois, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2703, name is Indian with a tinge of an RP accent, count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 2773, name is Greek, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2828, name is Kenyan English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2833, name is Afrikaans English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2856, name is Transnational englishes blend, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 2940, name is London English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2985, name is Midwestern, count is 4, locale is en, descriptors are '
#  'None, predetermined is False.')
# ("id is 3033, name is Porto des dels 3 anys aprenent anglès a l'escola i "
#  "actualment m'estic preparant per a l'examen del B2., count is 1, locale is "
#  'en, descriptors are None, predetermined is False.')
# ('id is 3085, name is Bangladeshi, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 3086, name is Bangladesh English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 3389, name is East Ukrainian , count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 3394, name is Southern England, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 3413, name is yorkshire, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 3422, name is i have some pronunciation issues because of oral surgery '
#  'and a hidden southern accent, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 3662, name is little bit classy little bit sassy and add some '
#  'city.....thats me, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 4049, name is eastern europe, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ("id is 4050, name is pronounced r's, count is 1, locale is en, descriptors "
#  'are None, predetermined is False.')
# ('id is 4051, name is heavy consonants , count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 4058, name is Norwegian, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4096, name is English north of England , count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4112, name is Latin English, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4318, name is slighty Southern affected by decades in the Midwest, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 4319, name is 4 years in Spain and Germany, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4320, name is speak some German, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 4321, name is Spanish, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 4322, name is Polish. Have lived in nine states., count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 4383, name is East Indian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4762, name is Japanese, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4839, name is French mid level accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4912, name is South African English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4918, name is international, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4919, name is Slovak, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 5046, name is Pittsburgh PA, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5213, name is polish accent, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5305, name is Educated Australian Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 5349, name is Midwestern United States English, count is 2, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 5365, name is Sydney - middle eastern seaboard Australian, count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 5390, name is West African , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5417, name is Latin American accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 5426, name is Lancashire, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5427, name is England , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5737, name is Swedish accent, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 5760, name is Kiwi, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 5964, name is Eastern European English, count is 2, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6398, name is Chicago , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 6472, name is American Midwest, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 6615, name is Spoke Chinese when little, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6616, name is 90% Pennsylvanian accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6617, name is 10% Chinese accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6942, name is South London and Essex, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6967, name is slight Brooklyn Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7029, name is Chicano English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7030, name is "Valley Girl" English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7271, name is A variety of Texan English with some German influence '
#  'that has undergone the cot-caught merger, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7448, name is new england/east coast, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7507, name is fluent, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7508, name is ESL, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7603, name is midwest, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7644, name is Israeli accent, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7714, name is Hmong-American, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7741, name is Okie, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7744, name is Kenyan , count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7774, name is Eastern European, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7846, name is polish, count is 4, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7962, name is Cool, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 8043, name is Mid-west United States English, count is 1, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 8233, name is south German / Swiss accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 8546, name is serbian, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 8710, name is bangladesh, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 8750, name is Nigerian English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 8779, name is Thai, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9337, name is With heavy Cantonese accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 9878, name is england, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9879, name is london, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9880, name is academic, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 9902, name is little latino, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 9904, name is second language, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 9948, name is 2nd Language , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 10100, name is International Indian Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 10142, name is minor french accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 10190, name is Upper Midwestern, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 10548, name is Dutch English, count is 2, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 11039, name is Mid-atlantic, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11197, name is Midatlantic, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11403, name is Italian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11459, name is Californian Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 11587, name is Midwestern States (Michigan), count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 11610, name is Ukrainian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11710, name is Javanese, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11711, name is Indonesian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 11843, name is Slight lisp, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12004, name is East European, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12009, name is try to maintain originality , count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12055, name is Some time spent in Scotland, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12056, name is mostly affecting inflection, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12057, name is I think, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12313, name is Austrian, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12362, name is Mid-Atlantic United States English, count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 12363, name is Philadelphia, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12364, name is Pennsylvania, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12367, name is Philadelphia Style United States English, count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 12553, name is South Texas, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12554, name is Slightly effeminate, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12555, name is Conversational, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12658, name is Midwestern US English (United States), count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 12843, name is southern english, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12844, name is sussex, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 12912, name is Mixed-Accent English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12949, name is Northern English, count is 2, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12958, name is CARIBBEAN AND BRITISH MIXED WITH SOME NEW YORK ACCENTS, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 12980, name is Foreign, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 13066, name is Pacific Northwest , count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13084, name is Bangladeshi English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13089, name is south-west German, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13090, name is South German accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13091, name is Alemannic German Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13631, name is Southern Californian, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13684, name is East African Khoja, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13940, name is Southwestern United States English, count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 14063, name is South London, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 14161, name is Northumbrian British English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 14262, name is Unite States Midwest, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 14305, name is Northern England, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 14479, name is New Orleans dialect, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 14585, name is Minnesotan, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 14741, name is Low, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 14742, name is Demure, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 15028, name is Liverpool English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 15029, name is Lancashire English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 15055, name is Non native speaker, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')

# %% [markdown]
# ---
# <a id='PreDetermined'></a>
# ## Label the accents that were pre-determined
#
# Since its inception, Mozilla Common Voice has enabled data contributors to enter demographic age such as age, gender and accent. These associations are not validated in any way, and we don't have any indicator of how accurate they are. Accent _used_ to be represented as an a priori drop-down list, which the contributor could select from. From Common Voice v10, the data contributor can **self-describe** their accent, however, the previous accent list is still presented (so may be more frequently chosen by the data contributor). We need to be able to distinguish these accents visually to help with the exploration.
#
# ```
# "splits": {
#         "accent": {
#           "": 0.51,
#           "canada": 0.03,
#           "england": 0.08,
#           "us": 0.23,
#           "indian": 0.07,
#           "australia": 0.03,
#           "malaysia": 0,
#           "newzealand": 0.01,
#           "african": 0.01,
#           "ireland": 0.01,
#           "philippines": 0,
#           "singapore": 0,
#           "scotland": 0.02,
#           "hongkong": 0,
#           "bermuda": 0,
#           "southatlandtic": 0,
#           "wales": 0,
#           "other": 0.01
#         },
#
# ```
#
# The `cv-datasets` splits above have labels for the accents that don't actually match the accent name in the data. So we need to specify the accents that are pre-determined. This is how they appear to the data contributor filling out their profile at: [https://commonvoice.mozilla.org/en/profile/info](https://commonvoice.mozilla.org/en/profile/info)
#
#
# ![Accents as specified on Mozilla Common Voice profile](cv-profile-specify-accent.png)

# %%
# create a list of the pre-existing accents 
# this is how they are given in the dataset. 

predetermined_accents_list = ['United States English', 
                         'England English', 
                         'India and South Asia (India, Pakistan, Sri Lanka)', 
                         'Canadian English', 
                         'Australian English', 
                         'Southern African (South Africa, Zimbabwe, Namibia)', 
                         'Irish English', 
                         'Scottish English', 
                         'New Zealand English', 
                         'Hong Kong English', 
                         'Filipino', 
                         'Malaysian English', 
                         'Singaporean English', 
                         'Welsh English', 
                         'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)', 
                         'South Atlantic (Falkland Islands, Saint Helena)']

# %%
# now, we iterate through both lists and if the ['accent'] in the Dict matches the accent in the predetermined list, 
# and add this as information in the dict that we can use for visualisation. 


for item in all_accents.items(): 
    #print('item is: ', item)
    key = item[0] 
    #print(key)
    
    predetermined_status = False
    
    for predetermined_accent in predetermined_accents_list: 
        
        #print('predetermined_accent is: ', predetermined_accent)
        #print('item 1 accent is: ', item[1]['accent'])
        
        if (predetermined_accent == item[1].name) :
            #print('MATCH!')
            predetermined_status = True
            
    all_accents[key].predetermined = predetermined_status
    #all_accents[key]['accent_predetermined'] = predetermined_status
    #print(all_accents[key]['accent_predetermined'])

# %%
for item in all_accents.items(): 
    pp.pprint(item[1].__str__())
# Out:
# ('id is 1, name is England English, count is 2342, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 2, name is United States English, count is 7537, locale is en, '
#  'descriptors are None, predetermined is True.')
# ('id is 3, name is Hong Kong English, count is 132, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 7, name is wolof, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9, name is Australian English, count is 665, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 11, name is Latin America, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 15, name is Southern African (South Africa, Zimbabwe, Namibia), count '
#  'is 260, locale is en, descriptors are None, predetermined is True.')
# ('id is 18, name is India and South Asia (India, Pakistan, Sri Lanka), count '
#  'is 2009, locale is en, descriptors are None, predetermined is True.')
# ('id is 31, name is Colombia, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 37, name is Canadian English, count is 896, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 58, name is Non native speaker from France, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 69, name is Scottish English, count is 171, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 78, name is New York City, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 85, name is Filipino, count is 126, locale is en, descriptors are '
#  'None, predetermined is True.')
# ('id is 86, name is French, count is 5, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 89, name is Argentinian English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ("id is 103, name is A'lo, count is 1, locale is en, descriptors are None, "
#  'predetermined is False.')
# ('id is 129, name is Finnish, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 133, name is Singaporean English, count is 77, locale is en, '
#  'descriptors are None, predetermined is True.')
# ('id is 139, name is West Indies and Bermuda (Bahamas, Bermuda, Jamaica, '
#  'Trinidad), count is 50, locale is en, descriptors are None, predetermined is '
#  'True.')
# ('id is 142, name is Hispanic/Latino, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 174, name is Non-native, count is 4, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 177, name is Georgian English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 188, name is Non native, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 200, name is Indo-Canadian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 208, name is New Zealand English, count is 163, locale is en, '
#  'descriptors are None, predetermined is True.')
# ('id is 257, name is Malaysian English, count is 98, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 276, name is California, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 301, name is Irish English, count is 188, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 313, name is Chinese, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 334, name is Midlands English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 376, name is french accent, count is 3, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 438, name is northern cali, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 442, name is nigeria english, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 445, name is English County Durham, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 470, name is Выраженный украинский акцент, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 474, name is Catalan, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 479, name is Polish English, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 486, name is European English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 488, name is Romanian, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 509, name is Welsh English, count is 67, locale is en, descriptors are '
#  'None, predetermined is True.')
# ('id is 561, name is Latino, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 629, name is British, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 667, name is German English, count is 8, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 700, name is Nigerian , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 708, name is Swedish English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 748, name is Spanish bilingual, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 760, name is Variable, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 773, name is Silicon Valley Native, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 778, name is United States English. people say I sound like a surffer '
#  'dude., count is 1, locale is en, descriptors are None, predetermined is '
#  'False.')
# ('id is 879, name is Liverpudlian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1011, name is I am German and speak English as learned at school, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1033, name is English with Swiss german accent, count is 1, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 1052, name is Japanese English, count is 2, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 1054, name is Mild Northern England English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1055, name is England non-native, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1076, name is Educated, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1077, name is non regional, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ("id is 1099, name is Israeli's accent , count is 1, locale is en, descriptors "
#  'are None, predetermined is False.')
# ('id is 1133, name is Dutch, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1134, name is European, count is 4, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1135, name is Adjustable, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1177, name is southern, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1178, name is formal, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1179, name is sultry, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1237, name is Basic, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1252, name is East London , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1317, name is Midwest USA speech blended with South Texas USA speech, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1337, name is German Accent, count is 3, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1485, name is Not bad, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1491, name is Midwest US... With some Canadian slang. , count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 1522, name is West Indian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1534, name is Northern, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1535, name is Urban, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1577, name is British English with a little bit of Russian, count is '
#  '1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1707, name is Northern Irish, count is 4, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 1721, name is United States English combined with European English, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1723, name is International English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1902, name is South Atlantic (Falkland Islands, Saint Helena), count '
#  'is 5, locale is en, descriptors are None, predetermined is True.')
# ('id is 1920, name is southern United States, count is 3, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1921, name is Russian, count is 6, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1938, name is pin/pen merger, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 1977, name is Southern Appalachian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1978, name is Southern United States English, count is 1, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 1998, name is United States English Pacific Northwest, count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 2174, name is Southern Texas Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 2191, name is midwestern US, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 2205, name is Midwest United States, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 2446, name is Mix of voices, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 2455, name is Colombian Accent, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2456, name is German, count is 5, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2571, name is Slavic, count is 6, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2630, name is Scottish, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 2685, name is Patois, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2703, name is Indian with a tinge of an RP accent, count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 2773, name is Greek, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2828, name is Kenyan English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2833, name is Afrikaans English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2856, name is Transnational englishes blend, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 2940, name is London English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2985, name is Midwestern, count is 4, locale is en, descriptors are '
#  'None, predetermined is False.')
# ("id is 3033, name is Porto des dels 3 anys aprenent anglès a l'escola i "
#  "actualment m'estic preparant per a l'examen del B2., count is 1, locale is "
#  'en, descriptors are None, predetermined is False.')
# ('id is 3085, name is Bangladeshi, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 3086, name is Bangladesh English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 3389, name is East Ukrainian , count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 3394, name is Southern England, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 3413, name is yorkshire, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 3422, name is i have some pronunciation issues because of oral surgery '
#  'and a hidden southern accent, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 3662, name is little bit classy little bit sassy and add some '
#  'city.....thats me, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 4049, name is eastern europe, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ("id is 4050, name is pronounced r's, count is 1, locale is en, descriptors "
#  'are None, predetermined is False.')
# ('id is 4051, name is heavy consonants , count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 4058, name is Norwegian, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4096, name is English north of England , count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4112, name is Latin English, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4318, name is slighty Southern affected by decades in the Midwest, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 4319, name is 4 years in Spain and Germany, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4320, name is speak some German, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 4321, name is Spanish, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 4322, name is Polish. Have lived in nine states., count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 4383, name is East Indian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4762, name is Japanese, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4839, name is French mid level accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4912, name is South African English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4918, name is international, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4919, name is Slovak, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 5046, name is Pittsburgh PA, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5213, name is polish accent, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5305, name is Educated Australian Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 5349, name is Midwestern United States English, count is 2, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 5365, name is Sydney - middle eastern seaboard Australian, count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 5390, name is West African , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5417, name is Latin American accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 5426, name is Lancashire, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5427, name is England , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5737, name is Swedish accent, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 5760, name is Kiwi, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 5964, name is Eastern European English, count is 2, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6398, name is Chicago , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 6472, name is American Midwest, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 6615, name is Spoke Chinese when little, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6616, name is 90% Pennsylvanian accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6617, name is 10% Chinese accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6942, name is South London and Essex, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6967, name is slight Brooklyn Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7029, name is Chicano English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7030, name is "Valley Girl" English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7271, name is A variety of Texan English with some German influence '
#  'that has undergone the cot-caught merger, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7448, name is new england/east coast, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7507, name is fluent, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7508, name is ESL, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7603, name is midwest, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7644, name is Israeli accent, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7714, name is Hmong-American, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7741, name is Okie, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7744, name is Kenyan , count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7774, name is Eastern European, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7846, name is polish, count is 4, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7962, name is Cool, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 8043, name is Mid-west United States English, count is 1, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 8233, name is south German / Swiss accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 8546, name is serbian, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 8710, name is bangladesh, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 8750, name is Nigerian English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 8779, name is Thai, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9337, name is With heavy Cantonese accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 9878, name is england, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9879, name is london, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9880, name is academic, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 9902, name is little latino, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 9904, name is second language, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 9948, name is 2nd Language , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 10100, name is International Indian Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 10142, name is minor french accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 10190, name is Upper Midwestern, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 10548, name is Dutch English, count is 2, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 11039, name is Mid-atlantic, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11197, name is Midatlantic, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11403, name is Italian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11459, name is Californian Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 11587, name is Midwestern States (Michigan), count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 11610, name is Ukrainian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11710, name is Javanese, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11711, name is Indonesian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 11843, name is Slight lisp, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12004, name is East European, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12009, name is try to maintain originality , count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12055, name is Some time spent in Scotland, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12056, name is mostly affecting inflection, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12057, name is I think, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12313, name is Austrian, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12362, name is Mid-Atlantic United States English, count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 12363, name is Philadelphia, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12364, name is Pennsylvania, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12367, name is Philadelphia Style United States English, count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 12553, name is South Texas, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12554, name is Slightly effeminate, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12555, name is Conversational, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12658, name is Midwestern US English (United States), count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 12843, name is southern english, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12844, name is sussex, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 12912, name is Mixed-Accent English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12949, name is Northern English, count is 2, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12958, name is CARIBBEAN AND BRITISH MIXED WITH SOME NEW YORK ACCENTS, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 12980, name is Foreign, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 13066, name is Pacific Northwest , count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13084, name is Bangladeshi English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13089, name is south-west German, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13090, name is South German accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13091, name is Alemannic German Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13631, name is Southern Californian, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13684, name is East African Khoja, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13940, name is Southwestern United States English, count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 14063, name is South London, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 14161, name is Northumbrian British English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 14262, name is Unite States Midwest, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 14305, name is Northern England, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 14479, name is New Orleans dialect, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 14585, name is Minnesotan, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 14741, name is Low, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 14742, name is Demure, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 15028, name is Liverpool English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 15029, name is Lancashire English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 15055, name is Non native speaker, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')

# %%
# sort the dict by count descending 
# I'm not using this actively but I want to know how to sort the Dict properly

all_accents_sorted_by_count = dict(sorted(all_accents.items(), key=lambda t:(t[1].count, t[1].name), reverse=True))


for item in all_accents.items(): 
    pp.pprint(item[1].__str__())
# Out:
# ('id is 1, name is England English, count is 2342, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 2, name is United States English, count is 7537, locale is en, '
#  'descriptors are None, predetermined is True.')
# ('id is 3, name is Hong Kong English, count is 132, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 7, name is wolof, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9, name is Australian English, count is 665, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 11, name is Latin America, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 15, name is Southern African (South Africa, Zimbabwe, Namibia), count '
#  'is 260, locale is en, descriptors are None, predetermined is True.')
# ('id is 18, name is India and South Asia (India, Pakistan, Sri Lanka), count '
#  'is 2009, locale is en, descriptors are None, predetermined is True.')
# ('id is 31, name is Colombia, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 37, name is Canadian English, count is 896, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 58, name is Non native speaker from France, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 69, name is Scottish English, count is 171, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 78, name is New York City, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 85, name is Filipino, count is 126, locale is en, descriptors are '
#  'None, predetermined is True.')
# ('id is 86, name is French, count is 5, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 89, name is Argentinian English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ("id is 103, name is A'lo, count is 1, locale is en, descriptors are None, "
#  'predetermined is False.')
# ('id is 129, name is Finnish, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 133, name is Singaporean English, count is 77, locale is en, '
#  'descriptors are None, predetermined is True.')
# ('id is 139, name is West Indies and Bermuda (Bahamas, Bermuda, Jamaica, '
#  'Trinidad), count is 50, locale is en, descriptors are None, predetermined is '
#  'True.')
# ('id is 142, name is Hispanic/Latino, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 174, name is Non-native, count is 4, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 177, name is Georgian English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 188, name is Non native, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 200, name is Indo-Canadian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 208, name is New Zealand English, count is 163, locale is en, '
#  'descriptors are None, predetermined is True.')
# ('id is 257, name is Malaysian English, count is 98, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 276, name is California, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 301, name is Irish English, count is 188, locale is en, descriptors '
#  'are None, predetermined is True.')
# ('id is 313, name is Chinese, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 334, name is Midlands English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 376, name is french accent, count is 3, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 438, name is northern cali, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 442, name is nigeria english, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 445, name is English County Durham, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 470, name is Выраженный украинский акцент, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 474, name is Catalan, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 479, name is Polish English, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 486, name is European English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 488, name is Romanian, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 509, name is Welsh English, count is 67, locale is en, descriptors are '
#  'None, predetermined is True.')
# ('id is 561, name is Latino, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 629, name is British, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 667, name is German English, count is 8, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 700, name is Nigerian , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 708, name is Swedish English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 748, name is Spanish bilingual, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 760, name is Variable, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 773, name is Silicon Valley Native, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 778, name is United States English. people say I sound like a surffer '
#  'dude., count is 1, locale is en, descriptors are None, predetermined is '
#  'False.')
# ('id is 879, name is Liverpudlian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1011, name is I am German and speak English as learned at school, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1033, name is English with Swiss german accent, count is 1, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 1052, name is Japanese English, count is 2, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 1054, name is Mild Northern England English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1055, name is England non-native, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1076, name is Educated, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1077, name is non regional, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ("id is 1099, name is Israeli's accent , count is 1, locale is en, descriptors "
#  'are None, predetermined is False.')
# ('id is 1133, name is Dutch, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1134, name is European, count is 4, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1135, name is Adjustable, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1177, name is southern, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1178, name is formal, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1179, name is sultry, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1237, name is Basic, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1252, name is East London , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1317, name is Midwest USA speech blended with South Texas USA speech, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1337, name is German Accent, count is 3, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1485, name is Not bad, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1491, name is Midwest US... With some Canadian slang. , count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 1522, name is West Indian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1534, name is Northern, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 1535, name is Urban, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1577, name is British English with a little bit of Russian, count is '
#  '1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1707, name is Northern Irish, count is 4, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 1721, name is United States English combined with European English, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 1723, name is International English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1902, name is South Atlantic (Falkland Islands, Saint Helena), count '
#  'is 5, locale is en, descriptors are None, predetermined is True.')
# ('id is 1920, name is southern United States, count is 3, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1921, name is Russian, count is 6, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 1938, name is pin/pen merger, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 1977, name is Southern Appalachian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 1978, name is Southern United States English, count is 1, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 1998, name is United States English Pacific Northwest, count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 2174, name is Southern Texas Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 2191, name is midwestern US, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 2205, name is Midwest United States, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 2446, name is Mix of voices, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 2455, name is Colombian Accent, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2456, name is German, count is 5, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2571, name is Slavic, count is 6, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2630, name is Scottish, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 2685, name is Patois, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2703, name is Indian with a tinge of an RP accent, count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 2773, name is Greek, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 2828, name is Kenyan English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2833, name is Afrikaans English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2856, name is Transnational englishes blend, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 2940, name is London English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 2985, name is Midwestern, count is 4, locale is en, descriptors are '
#  'None, predetermined is False.')
# ("id is 3033, name is Porto des dels 3 anys aprenent anglès a l'escola i "
#  "actualment m'estic preparant per a l'examen del B2., count is 1, locale is "
#  'en, descriptors are None, predetermined is False.')
# ('id is 3085, name is Bangladeshi, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 3086, name is Bangladesh English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 3389, name is East Ukrainian , count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 3394, name is Southern England, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 3413, name is yorkshire, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 3422, name is i have some pronunciation issues because of oral surgery '
#  'and a hidden southern accent, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 3662, name is little bit classy little bit sassy and add some '
#  'city.....thats me, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 4049, name is eastern europe, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ("id is 4050, name is pronounced r's, count is 1, locale is en, descriptors "
#  'are None, predetermined is False.')
# ('id is 4051, name is heavy consonants , count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 4058, name is Norwegian, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4096, name is English north of England , count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4112, name is Latin English, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4318, name is slighty Southern affected by decades in the Midwest, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 4319, name is 4 years in Spain and Germany, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4320, name is speak some German, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 4321, name is Spanish, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 4322, name is Polish. Have lived in nine states., count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 4383, name is East Indian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4762, name is Japanese, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4839, name is French mid level accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4912, name is South African English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 4918, name is international, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 4919, name is Slovak, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 5046, name is Pittsburgh PA, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5213, name is polish accent, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5305, name is Educated Australian Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 5349, name is Midwestern United States English, count is 2, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 5365, name is Sydney - middle eastern seaboard Australian, count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 5390, name is West African , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5417, name is Latin American accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 5426, name is Lancashire, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5427, name is England , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 5737, name is Swedish accent, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 5760, name is Kiwi, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 5964, name is Eastern European English, count is 2, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6398, name is Chicago , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 6472, name is American Midwest, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 6615, name is Spoke Chinese when little, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6616, name is 90% Pennsylvanian accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6617, name is 10% Chinese accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6942, name is South London and Essex, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 6967, name is slight Brooklyn Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7029, name is Chicano English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7030, name is "Valley Girl" English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7271, name is A variety of Texan English with some German influence '
#  'that has undergone the cot-caught merger, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7448, name is new england/east coast, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 7507, name is fluent, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7508, name is ESL, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7603, name is midwest, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7644, name is Israeli accent, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7714, name is Hmong-American, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7741, name is Okie, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7744, name is Kenyan , count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7774, name is Eastern European, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 7846, name is polish, count is 4, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 7962, name is Cool, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 8043, name is Mid-west United States English, count is 1, locale is '
#  'en, descriptors are None, predetermined is False.')
# ('id is 8233, name is south German / Swiss accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 8546, name is serbian, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 8710, name is bangladesh, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 8750, name is Nigerian English, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 8779, name is Thai, count is 2, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9337, name is With heavy Cantonese accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 9878, name is england, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9879, name is london, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 9880, name is academic, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 9902, name is little latino, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 9904, name is second language, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 9948, name is 2nd Language , count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 10100, name is International Indian Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 10142, name is minor french accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 10190, name is Upper Midwestern, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 10548, name is Dutch English, count is 2, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 11039, name is Mid-atlantic, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11197, name is Midatlantic, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11403, name is Italian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11459, name is Californian Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 11587, name is Midwestern States (Michigan), count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 11610, name is Ukrainian, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11710, name is Javanese, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 11711, name is Indonesian English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 11843, name is Slight lisp, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12004, name is East European, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12009, name is try to maintain originality , count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12055, name is Some time spent in Scotland, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12056, name is mostly affecting inflection, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12057, name is I think, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12313, name is Austrian, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12362, name is Mid-Atlantic United States English, count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 12363, name is Philadelphia, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12364, name is Pennsylvania, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12367, name is Philadelphia Style United States English, count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 12553, name is South Texas, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 12554, name is Slightly effeminate, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12555, name is Conversational, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12658, name is Midwestern US English (United States), count is 1, '
#  'locale is en, descriptors are None, predetermined is False.')
# ('id is 12843, name is southern english, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12844, name is sussex, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 12912, name is Mixed-Accent English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 12949, name is Northern English, count is 2, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 12958, name is CARIBBEAN AND BRITISH MIXED WITH SOME NEW YORK ACCENTS, '
#  'count is 1, locale is en, descriptors are None, predetermined is False.')
# ('id is 12980, name is Foreign, count is 2, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 13066, name is Pacific Northwest , count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13084, name is Bangladeshi English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13089, name is south-west German, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13090, name is South German accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13091, name is Alemannic German Accent, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13631, name is Southern Californian, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13684, name is East African Khoja, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 13940, name is Southwestern United States English, count is 1, locale '
#  'is en, descriptors are None, predetermined is False.')
# ('id is 14063, name is South London, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 14161, name is Northumbrian British English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 14262, name is Unite States Midwest, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 14305, name is Northern England, count is 1, locale is en, descriptors '
#  'are None, predetermined is False.')
# ('id is 14479, name is New Orleans dialect, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 14585, name is Minnesotan, count is 1, locale is en, descriptors are '
#  'None, predetermined is False.')
# ('id is 14741, name is Low, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 14742, name is Demure, count is 1, locale is en, descriptors are None, '
#  'predetermined is False.')
# ('id is 15028, name is Liverpool English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 15029, name is Lancashire English, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')
# ('id is 15055, name is Non native speaker, count is 1, locale is en, '
#  'descriptors are None, predetermined is False.')

# %%
"""
predetermined_accents_list = ['United States English', 
                         'England English', 
                         'India and South Asia (India, Pakistan, Sri Lanka)', 
                         'Canadian English', 
                         'Australian English', 
                         'Southern African (South Africa, Zimbabwe, Namibia)', 
                         'Irish English', 
                         'Scottish English', 
                         'New Zealand English', 
                         'Hong Kong English', 
                         'Filipino', 
                         'Malaysian English', 
                         'Singaporean English', 
                         'Welsh English', 
                         'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)', 
                         'South Atlantic (Falkland Islands, Saint Helena)']
"""

"""
List of accents that should be merged into one canonical one for the purpose of analysis 

667, 2456, 1337, 4320 - German and German English and 'German Accent', speak some German

2985, 5349, 2191, 7603, 14262, 11587, 2205, 1317, 1491, 8043, 6472 - Midwestern United States variants 
1978 - and others - southern united states variants 

10548, 1133 - Dutch English and Dutch

7846, 5213, 479 -  polish and 'polish accent' and 'Polish English'

9878 - 'england' and 'England English'

4049, 12004 - 'eastern european English' and 'eastern Europe'

5737, 708 - 'swedish' and 'swedish english'

12363 and others - 'Philadelphia' and variants

14305, 1054, 4096 and others - 'Northern English'

15055, 188 and others 'non-native speaker'

8750, 700 and others - 'Nigerian English' 

11039, 12362 and others - 'Mid-atlantic'

2040 and others - 'London' and variants

879, 15028 - 'Liverpool' and variants 

5417, 11 and others - 'Latin American' and variants

15029, 5426 - 'Lancashire'

2828, 7744 - 'Kenyan'

There are at least two Japanese accents in the dataset. 

1099, 7644 - Israeli 

There are many Hispanic / Latino / Latin accent descriptors in the dataset. 

Several German and Swiss German Accents definitions - South German appears to be similar to Swiss, so I wouldn't separate them 

7774 - 'European English' and 'European'

Second language and 'ESL' should be combined into 'English as a Second Language' - it's a different type of 'non-native descriptor'

2455 and 31 - Colombian 

11459 and 276 - 'California' and 'Californian Accent'

13084, 3085, 3086 and others - variants of 'Bangladeshi English'

9948 -  '2nd Language ' - and others - variants of "second language" or "ESL"

"""



"""
Modifications that should be made 

Countries should be uppercased - Polish 
Capital case for accents - 'southern United States'

"""

"""
Notation logs 

* Northern Irish is categorised as a Country descriptor because Northern Ireland is a country in the United Kingdom* Serbian is categorised as a Country descriptor because Serbia is a country in its own right  it's no longer Yugoslavia
* Similarly, Scottish is categorised as a Country descriptor

Is it a country descriptor or is it a language descriptor?
Some countries have a language that tends to overlap its nation state borders - Germany, Austria, French, Polish
So it's both a country and a language description 
Slavic is a language group, as is Latino too. 

So that needs to come out in the analysis. 

Strength of accent appears to be another descriptor - so 'slight Brooklyn accent'

Is fluency the same as an Ln descriptor? For these purposes I think we can say so. 

Cantonese has been classified as sub-national - primarily because Hong Kong is a part of China, however there are many Cantonese diaspora in the world. 
Should it be classified as supra-national, as is Wolof? 
This might be a better classification, because of the many countries in which Cantonese is spoken (Singapore etc.
A different way to approach this might be to have a category which is "Language group descriptor"

'English County Durham' is distinct even when within Northumbrian English - so the two were not merged. 

AMBIGUOUS ACCENT DESCRIPTORS 

The accent descriptor 'West Indian' is ambiguous - does it refer to West Indies, or West India? I have categorised it as West India because there is an existing West Indies pre-determined category. 

The accent descriptor 'Low' is ambiguous - does it refer to low Midwestern or tonal low range? I have categorised it is Low Midwestern

The accent 'East Indian' is ambiguous - it co-occurred with Indian rather than say Dutch East Indies, so categorising it as subnational region.

The accent "A'lo" is ambiguous - based on its Spanish translation I am categorising it as a fluency marker. Elemento prefijal de origen griego que entra en la formación de nombres y adjetivos con el significado de ‘otro’, ‘diferente’.

'"Valley Girl" English' is ambiguous - is it a regional descriptor or is it a register? 
I have categorised it as a register because the features of the accent are also changes to words and pronunciation. 
It's not just Californian _accent_ - it's a register change, like, you know, awesome :D 

6615 - Spoke Chinese when little - is this another category for speaking a language in childhood and then having a different accent when you grow up? 
1237- Basic - this could be interpreted as a register or a fluency level. Choosing to categorise as a fluency level because it co-occurs with Indian, which culturally doesn't have a "Basic" register. 
https://en.wikipedia.org/wiki/Basic_(slang)


DISCARDED as regex artefacts 
12057: {'accent': 'I think', 'count': 1, 'accent_predetermined': False}

"""

"""
All accents coded. 

"""

accent_category_descriptors = [('Country descriptor'), 
                               ('Supranational region descriptor'),
                               ('Subnational region descriptor'),
                               ('City descriptor'),
                               ('Ln descriptor'),
                               ('Vocal quality descriptor'),
                               ('Accent strength descriptor'),
                               ('Rhoticity'),
                               ('Phoneme changes'),
                               ('Inflection changes'),
                               ('Register'), 
                               ('Accent effects due to physical changes')
                               ('Unknown or other'),
                              
                              
                              ]

accent_category_rules = [
    
    
    
                        ## COUNTRY DESCRIPTORS 
    
                         ('German English', 'Country descriptor' ),
                         ('German', 'Country descriptor' ),
                         ('German Accent', 'Country descriptor' ),
                         ('speak some German', 'Country descriptor' ),
                         ('I am German and speak English as learned at school', 'Country descriptor' ),
    
                        
                         
                         
                         
                         ('Russian', 'Country descriptor' ),
                            ('British English with a little bit of Russian', 'Country descriptor' ),
    
                         ('Ukrainian', 'Country descriptor' ),
                            ('Georgian English', 'Country descriptor' ),
                            ('Finnish', 'Country descriptor' ),
    
  
                         
    
                         ('Northern Irish', 'Country descriptor' ),
                         ('Scottish', 'Country descriptor' ),
                        ('England ', 'Country descriptor' ),
                            
    
   
    
    
                         ('polish', 'Country descriptor' ),
                         ('polish accent', 'Country descriptor' ),
                         ('Polish. Have lived in nine states.', 'Country descriptor' ),
                         ('Polish English', 'Country descriptor' ),
                            
    
    
                            ( 'Italian', 'Country descriptor' ),
    
    
                           
    
                         ('Slovak', 'Country descriptor' ),
                         
                         ('french accent', 'Country descriptor' ),
                         ('minor french accent', 'Country descriptor' ),
                         ('Non native speaker from France', 'Country descriptor' ),
                            
                         ('French mid level accent', 'Country descriptor' ),
    
                        
                         
                         
                         ('Spanish bilingual', 'Country descriptor' ),
                        ('4 years in Spain and Germany', 'Country descriptor' ),
                            
                
    
                         ('Greek', 'Country descriptor'), 
                         
                         
                         
                         ('Swedish accent', 'Country descriptor' ),
                         ('Swedish English', 'Country descriptor' ),
                         
                         
                         
                         
                         
                         ('england', 'Country descriptor' ),
                         
                         
                         ('Thai', 'Country descriptor' ),
                         ('Chinese', 'Country descriptor' ),
                         ('10% Chinese accent', 'Country descriptor' ),
                             
    
                         
    
                         ('Romanian', 'Country descriptor' ),
                         ('Spanish', 'Country descriptor' ),
                         ('Norwegian', 'Country descriptor' ),
                         
                         ('Japanese English', 'Country descriptor' ),
                         ('Japanese', 'Country descriptor' ),
                         
    
    
                         ('Spoke Chinese when little', 'Country descriptor' ),
                         
                         
                         ('Dutch English', 'Country descriptor' ),
                         ('Dutch', 'Country descriptor' ),
                         ('British', 'Country descriptor' ),
                         ('Austrian', 'Country descriptor' ),
                         ('Выраженный украинский акцент', 'Country descriptor' ),
                         ('serbian', 'Country descriptor' ),
    
    
                         ('nigeria english', 'Country descriptor' ),
                         ('Nigerian English', 'Country descriptor' ),
                         ('Nigerian ', 'Country descriptor' ),
                         
    
   
                         ('South African English', 'Country descriptor' ),
    
                         ('Kenyan English', 'Country descriptor' ),
                            ('Kenyan ', 'Country descriptor' ),
                        
                        
                        ("Israeli's accent ", 'Country descriptor' ),
                        ('Israeli accent', 'Country descriptor' ),
    
                        ('International Indian Accent', 'Country descriptor' ),
                        ('Indo-Canadian English', 'Country descriptor' ),
                            
    
                            
                        ('Indonesian English', 'Country descriptor' ),
                        
                            
    
                         
                         ('bangladesh', 'Country descriptor' ),
                            ('Bangladeshi English', 'Country descriptor' ),
                            ('Bangladeshi', 'Country descriptor' ),
                            ('Bangladesh English', 'Country descriptor' ),
                            
    
                        
    
                        ('Kiwi', 'Country descriptor' ),
                        
    ('Colombian Accent', 'Country descriptor' ),
    ('Colombia', 'Country descriptor' ),
    ('Argentinian English', 'Country descriptor' ),
    
                         
                         
                         
                         
                         ## SUBNATIONAL REGION DESCRIPTORS 
                         
                         ('Midwestern', 'Subnational region descriptor' ),
                         ('Midwestern United States English', 'Subnational region descriptor' ),
                         ('midwestern US', 'Subnational region descriptor' ),
                         ('midwest', 'Subnational region descriptor' ),
                         ('Upper Midwestern', 'Subnational region descriptor' ),
                         ('Unite States Midwest', 'Subnational region descriptor' ),
                         ('Minnesotan', 'Subnational region descriptor' ),
                            ('Midwestern US English (United States)', 'Subnational region descriptor' ),
                        ('Midwestern States (Michigan)', 'Subnational region descriptor' ),
                        ('Midwest United States', 'Subnational region descriptor' ),
                        ('Midwest USA speech blended with South Texas USA speech', 'Subnational region descriptor' ),
    
                         ('Mid-west United States English', 'Subnational region descriptor' ),
                        ('American Midwest', 'Subnational region descriptor' ),
    
    
    
                        ( 'Low', 'Subnational region descriptor', 'this co-occurred with mid-western, so I think it means Low MidWestern' ),
    
            
                        
                        
                        
                        
    
    
    
    
    
    
    
    
                         ('Southern Appalachian English', 'Subnational region descriptor' ),
                         ('Okie', 'Subnational region descriptor' ),
                         ('Northern', 'Subnational region descriptor', 'co-occurred with American English so grouped here')
    
    
    
                         
                                                 
                         
                         ('southern United States', 'Subnational region descriptor' ),
                         ('Southern United States English', 'Subnational region descriptor' ),
                         ('Southwestern United States English', 'Subnational region descriptor' ),
                         ('Southern Texas Accent', 'Subnational region descriptor' ),
                         ('South Texas', 'Subnational region descriptor' ),
                            ('A variety of Texan English with some German influence that has undergone the cot-caught merger', 'Subnational region descriptor' ),
                        
    
    
                         
                
                         ('slighty Southern affected by decades in the Midwest', 'Subnational region descriptor' ),
                         ('northern cali', 'Subnational region descriptor' ),
                         ('Southern Californian', 'Subnational region descriptor' ),
                         ('Silicon Valley Native', 'Subnational region descriptor' ),                         
                        ('Californian Accent', 'Subnational region descriptor' ),
                        ('California', 'Subnational region descriptor' ),
    
    
                         
                         ('new england/east coast', 'Subnational region descriptor' ),
                         ('Philadelphia Style United States English', 'Subnational region descriptor' ),
                         ('Philadelphia', 'Subnational region descriptor' ),
                         ('Pennsylvania', 'Subnational region descriptor' ),
                        ('90% Pennsylvanian accent', 'Subnational region descriptor' ),
                         
    
    
    
                            
    
                         ('United States English Pacific Northwest', 'Subnational region descriptor' ),
                         ('Pacific Northwest ', 'Subnational region descriptor' ),
    
    
                         ('Midatlantic', 'Subnational region descriptor' ),
                        ('Mid-atlantic', 'Subnational region descriptor' ),
                        ('Mid-Atlantic United States English', 'Subnational region descriptor' ),
                        
    
                            
    
    
                         
                         
                         
                         
                         
                         ('yorkshire', 'Subnational region descriptor' ),
                         ('Northern English', 'Subnational region descriptor' ),
                         ('Northern English', 'Subnational region descriptor' ),
                          ('Northern England', 'Subnational region descriptor' ),
                          ('Mild Northern England English', 'Subnational region descriptor' ),
                            ('English north of England ', 'Subnational region descriptor' ),
                            
                         
                         
                            
                         ('Northumbrian British English', 'Subnational region descriptor' ),
                            ('English County Durham', 'Subnational region descriptor' ),
    
    
    
                        ('Midlands English', 'Subnational region descriptor' ),
                        ('Lancashire English', 'Subnational region descriptor' ),
                        ('Lancashire', 'Subnational region descriptor' ),
                        
                        
                        
    
                            
                         ('sussex', 'Subnational region descriptor' ),
                         ('southern english', 'Subnational region descriptor' ),
                         ('Southern England', 'Subnational region descriptor' ),
                         ('South London and Essex', 'Subnational region descriptor' ),
    
    
                         
                         
                         ('southern', 'Subnational region descriptor' ),
                         ('south-west German', 'Subnational region descriptor' ),
                         ('south German / Swiss accent', 'Subnational region descriptor' ),
                         ('English with Swiss german accent', 'Subnational region descriptor' ),
                        
                         ('South German accent', 'Subnational region descriptor' ),
                         ('Alemannic German Accent', 'Subnational region descriptor' ),
                        
    
                         
                         ('With heavy Cantonese accent', 'Subnational region descriptor'), 
    
                         ('Javanese', 'Subnational region descriptor'), 
    
                            
                         
                         ('West Indian', 'Subnational region descriptor' ),
                         ('East Indian', 'Subnational region descriptor' ),
    
    
                         ('East Ukrainian', 'Subnational region descriptor' ),
                            
    
                        ('Catalan', 'Subnational region descriptor' ),
                        
                         
                         
                         ## CITY DESCRIPTORS 
                         
                        
                         
                         ('Sydney - middle eastern seaboard Australian', 'City descriptor'), 
    
    
                      
                          ('London English', 'City descriptor'), 
                           
                            ('london', 'City descriptor'), 
                        
    
    
                            ('Liverpudlian English', 'City descriptor'), 
                            ('Liverpool English', 'City descriptor'), 
    
    
                            
                         ('New York City', 'City descriptor')
                         ('New Orleans dialect', 'City descriptor')

                        
                        ('Chicago ', 'City descriptor')
                        
    
    
    
                        ## SUB-CITY DESCRIPTORS 
    
     ('slight Brooklyn Accent', 'Sub-city descriptor'), 
     ('East London ', 'Sub-city descriptor'), 
       ('South London', 'Sub-city descriptor'), 
                         
                         
                         ## SUPRANATIONAL DESCRIPTORS 
                                   
                         ('Slavic', 'Supranational region descriptor' ),
                         ('European', 'Supranational region descriptor' ),
                            ('European English', 'Supranational region descriptor' ),
    
    
                         ('Latino', 'Supranational region descriptor' ),
                         ('little latino', 'Supranational region descriptor' ),
                            ('Chicano English', 'Supranational region descriptor' ),
                         
    
    
                         ('Eastern European English', 'Supranational region descriptor' ),
                         ('eastern europe', 'Supranational region descriptor' ),
                        ('Eastern European', 'Supranational region descriptor' ),
                        ( 'East European', 'Supranational region descriptor' ),
                        
    
   
    
    
    
    
    
                        
                        
                         
                         
                         ('wolof', 'Supranational region descriptor' ),
                         ('West African ', 'Supranational region descriptor' ),
                         ('East African Khoja', 'Supranational region descriptor' ),
                            ('Afrikaans English', 'Supranational region descriptor' ),
                        
  
    
                         ('Hmong-American', 'Supranational region descriptor' ),
                         
    
                          ('Latin English', 'Supranational region descriptor' ),
                            ('Latin American accent', 'Supranational region descriptor' ),
                           ( 'Hispanic/Latino', 'Supranational region descriptor' )
    
                        
                         
                         
                         ## L1 OR L2 NATIVE / FLUENCY DESCRIPTORS 
                         
                         ('Non-native', 'Ln descriptor' ),
                         ('Non native speaker', 'Ln descriptor' ),
                         ('Non native', 'Ln descriptor' ),
    
    
                            ('England non-native', 'Ln descriptor' ),
                            
    
                         ('Foreign', 'Ln descriptor' ),
                         ('second language', 'Ln descriptor' ),
                         ( '2nd Language ', 'Ln descriptor' ),
                       
                         
    
                        ('ESL', 'Ln descriptor'),
                        
    
                        ( "A'lo", 'Ln descriptor'),
    
                       
    
                        ## FLUENCY DESCRIPTOR
    
    
    ('fluent', 'Ln descriptor'),
     
    ('Conversational', 'Ln descriptor'),
    
     ('Basic', 'Ln descriptor'),
    
    
    
                         
                         
                         ## VOCAL QUALITY DESCRIPTORS 
                         ('sultry', 'Vocal quality descriptor'),
                         ('Slightly effeminate', 'Vocal quality descriptor'),
                        ('Demure', 'Vocal quality descriptor'),
    
    
    
    
    
                            
                         ## SPECIFIC PHONETIC CHANGES 
                          
                         ("pronounced r's",'Rhoticity'),
                          
                         ('pin/pen merger', 'Phoneme changes'),
                         ('heavy consonants', 'Phoneme changes'),
                    
                         ('Slight lisp', 'Phoneme changes'),
    
                         
                          
                         ('mostly affecting inflection', 'Inflection changes'),
                         
                         ('i have some pronunciation issues because of oral surgery and a hidden southern accent', 'Accent effects due to physical changes'
                          
                          ## SPOKEN REGISTER
                          
                          ('formal', 'Register'),
                          ('academic', 'Register'),
                          ('Urban', 'Register'),
                          ('United States English. people say I sound like a surffer dude.', 'Register'),
                          ('Midwest US... With some Canadian slang.', 'Register'),
                          
                          ('Educated Australian Accent', 'Register'),
                          ('Educated', 'Register'),
                          ('Cool', 'Register'),
                          ('"Valley Girl" English', 'Register'),
                          
                          
                          
                            
                          
                         ## NOT SURE HOW TO GROUP THESE ONES YET 
                         
                         ('try to maintain originality' , 'Unknown or other' ),
                         ('non regional' , 'Unknown or other' ),
                         ('little bit classy little bit sassy and add some city.....thats me', 'Unknown or other'),
                         ('international', 'Unknown or other'),
                          
                          
                          ## MIX OF ACCENTS
                          
                        ('Mixed-Accent English', 'Unknown or other'),
                          ('Mix of voices', 'Unknown or other'),
                          
                          
                          ## ACCENT WHICH VARIES
                          
                         ('Variable', 'Unknown or other'),
                         ('Adjustable', 'Unknown or other'),
                          
                          
                          ('Transnational englishes blend', 'Unknown or other'),
                        ('International English', 'Unknown or other'),
                            ('CARIBBEAN AND BRITISH MIXED WITH SOME NEW YORK ACCENTS', 'Unknown or other'),
                          
                          
                          
                          
                          
                          ## DIALECT DESCRIPTOR
                          ('Patois', 'Unknown or other'),
                          
                          
                          
                          ## STRENGTH OF ACCENT 
                          ('Not bad', 'Unknown or other'),
# Out:
#   Cell In [147], line 400
#     ('Northern England', 'Subnational region descriptor' ),
#     ^
# SyntaxError: invalid character in identifier

# %%
## Creating linkages between the individual accents and how they are represented in the data. 
## What I want to do here is create a data structure that has the ID of the accent and something to describe the edge: 
## 
## The data structure I think will work here is: 
## 
## { 99: (123, 456, 789)} 
## to represent each combination of accents 

## The data structures we are using are: 
## 
## all_accents_sorted_by_count - this is a Dict of all the *individual accents* with a count and predetermined status
## english_accents_list - this is a *string* of accents, comma separated, that requires
## 
## what we want to do is go through each list, 
## and find the ID number of the accent 
## from the Dict, 
## then build another data structure that represents the row, and the accents in it. 

## accent list is a String 

accent_nodes = {}
i = 0;

for accent_list in english_accents_list:
    
    # this regex is from 
    # https://stackoverflow.com/questions/26633452/how-to-split-by-commas-that-are-not-within-parentheses
    accent_list=re.split(',\s*(?![^()]*\))', accent_list[0])
    
    print('number of items in accent_list is: ', len(accent_list))
    
    
    # initialise the list first 
    accent_nodes[i] = []
    
    for accent_list_item in accent_list: 
        #print('now processing', accent_list_item)
        
        node_cnt = 0; 
        
        for accent in all_accents_sorted_by_count.items(): 
            
            if (i%ratio_display ==0): # only show the 100th 
                print('---')
                print ('now looking at row: ', accent_list, 'and accent list item: ', accent_list_item, ' and accent: ', accent)
        
            if (accent_list_item == accent[1]['accent']): ## match 
                
                if (i%ratio_display ==0): # only show the 100th 
                    print('---')
                    print ('match!')
                    
                print(accent[0])
                print('i is: ', i, ' and node_cnt is: ', node_cnt)
                
                accent_nodes[i].append(accent[0]) # we want the accent ID number
                node_cnt +=1
                
     
    i +=1

# %%
print(accent_nodes)
print(accent_nodes[0])
print(len(accent_nodes[0]))

# %%
print(english_accents_list[27])
print(all_accents[2])
print(all_accents[37])
print(all_accents[200])

print(english_accents_list[156])
print(all_accents[133])
print(all_accents[257])


## this is a cross-check
## the other cross check is to make sure that the ID numbers in the lists above match with all_accents. 
## I've done this for a couple just to make sure, e.g.

## 27: [2, 37, 200]
## 156: [133, 257]

# %% [markdown]
# ## Now that we have node data, we can start to build a picture of the nodes of accents - which accents are more commonly linked to each other?

# %%
## what we want to do here is loop through the accent_nodes Dict 
## and create another Dict that we can use to create Links between the Nodes (which are accents)

accent_links = {} 
accent_link_id = 0

print(len(accent_nodes)) 

# we want to create a new structure, as we'll be popping elements off, and we want to leave accent_nodes untouched

for accent_list in accent_nodes.items(): 
    print('accent list is: ', accent_list)
    
    if len(accent_list[1]) > 1: 
        # we want to create links 
        
        while (len(accent_list[1]) > 1) : 
            print('\n')
            print('accent list stack size is greater than 1, now in while loop')
            
            popped_element = accent_list[1].pop(0) # remove the first element 
            print('popped element is :', popped_element)
            
            accent_links[accent_link_id] = {}
            
            # create links between the popped element and all the remaining elements in the list 
            for accent_id in accent_list[1]: 
                
                print('--- in accent list loop ---')
                print('accent_id is: ', accent_id)
                print('length of accent list is: ', len(accent_list[1]))
                
                accent_links[accent_link_id]['source'] = popped_element
                accent_links[accent_link_id]['target'] = accent_id
                accent_links[accent_link_id]['value'] = 1 # we can alter this later
            
                print(accent_links[accent_link_id])
                
        accent_link_id +=1
                
                
        print('end of while loop')
        print('\n')

# %%
print(accent_links)

# %%
# Output the dict to JSON 

with open("all_accents.json", "w") as outfile: 
    json.dump(all_accents_sorted_by_count, outfile)

# %% [markdown]
# ## Define a
#
# What I want to do here is define an Accent class which should make it easier to work with.

# %%
accentClassDict = {} # Dict of Accent objects

dummyDescriptor1 = AccentDescriptor(999999, 'dummy1', 'definition1')
dummyDescriptor2 = AccentDescriptor(888888, 'dummy2', 'definition2')

pp.pprint(str(dummyDescriptor1))
pp.pprint(str(dummyDescriptor2))

for accent in all_accents.items(): 
    #pp.pprint(accent)
    accentClassDict[accent[0]] = Accent(accent[0], accent[1]['accent'], accent[1]['count'], 'en', (dummyDescriptor1, dummyDescriptor2), accent[1]['accent_predetermined'])
    

    
pp.pprint(accentClassDict[12958])
pp.pprint(str(accentClassDict[12958])) # reference the Dict by idx

for idx, item in accentClassDict.items(): 
    #print(idx, item)
    pp.pprint(str(item))
