# %% [markdown]
# # Working with accent data in the Mozilla Common Voice dataset
#
# The purpose of this Python Jupyter notebook is to provide some worked examples of how you might explore accent data in the Common Voice dataset.
#
# ## Background information on demographic data in Common Voice
#
# Before you start working with accent data in Common Voice, there is background information you should know about the data structures in the Common Voice datasets, and how accents have been represented.
#
# ### The ability to choose whether or not to specify demographic information
#
# Data contributors can contribute voice data to Common Voice with our without logging in to the platform. If a data contributor is not logged in, the utterances they record contain no demographic metadata information, such as the gender, age range or accent of the speaker. If the data contributor _does_ log in, then they can choose whether to specify demographic information in their profile. Part of the demographic information can include specifying which accent(s) they speak with.
#
#
# Since mid 2021, data contributors to the Common Voice dataset have been able to self-specify descriptors for their accents.
#
# The purpose of this script is to get demographic details from an MCV downloaded dataset.
# This informs decision making around, for example, how much of the data in a particular language, has demographic details, and if so, what they are.

# %%
# imports go here 

# io 
import io

# pandas 
import pandas as pd

# %%
# specify the path to the TSV file - this should be `validated.tsv` from the MCV download 
#filePath = '/media/kathyreid/Seagate Backup Plus Drive/cv-datasets/ru/validated.tsv'
#filePath = '/media/kathyreid/Seagate Backup Plus Drive/cv-datasets/fr/validated.tsv'
#filePath = '/media/kathyreid/Elements/de/validated.tsv'
#filePath = '/media/kathyreid/Elements/es/validated.tsv'
#filePath = '/media/kathyreid/Elements/en/validated.tsv'
#filePath = '/media/kathyreid/Seagate Backup Plus Drive/cv-datasets/en-v9/validated.tsv'
filePath = '/media/kathyreid/Elements/cv-corpus-11.0-2022-09-21/en/validated.tsv'

# put it into a DataFrame 
df = pd.read_csv(filePath, sep='\t')

# %%
# summary data 
df.value_counts
# Out:
# <bound method DataFrame.value_counts of                                                  client_id  \
# 0        000abb3006b78ea4c1144e55d9d158f05a9db011016051...
# 1        0013037a1d45cc33460806cc3f8ecee9d536c45639ba4c...
# 2        0014c5a3e5715a54855257779b89c2bb498d470b225866...
# 3        001509f4624a7dee75247f6a8b642c4a0d09f8be3eeea6...
# 4        001519f234e04528a2b36158c205dbe61c8da45ab0242f...
# ...                                                    ...
# 1556249  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 1556250  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 1556251  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 1556252  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 1556253  372293e65cdab88771e028a4351651ab2eff64438ddafc...
#
#                                  path  \
# 0        common_voice_en_27710027.mp3
# 1          common_voice_en_699711.mp3
# 2        common_voice_en_21953345.mp3
# 3        common_voice_en_18132047.mp3
# 4        common_voice_en_27340672.mp3
# ...                               ...
# 1556249  common_voice_en_31747485.mp3
# 1556250  common_voice_en_31747533.mp3
# 1556251  common_voice_en_31747636.mp3
# 1556252  common_voice_en_31747771.mp3
# 1556253  common_voice_en_31747838.mp3
#
#                                                   sentence  up_votes  \
# 0        Joe Keaton disapproved of films, and Buster al...         3
# 1                                     She'll be all right.         2
# 2                                                      six         3
# 3                               All's well that ends well.         2
# 4        It is a busy market town that serves a large s...         2
# ...                                                    ...       ...
# 1556249  According to The Guardian he lives in the Caym...         2
# 1556250  It is spatially distributed as either scattere...         2
# 1556251                 The exhibition had two main parts.         2
# 1556252                 The story is told in two segments.         2
# 1556253  Credits are adapted from Tidal and Tower Recor...         2
#
#          down_votes      age gender                            accents locale  \
# 0                 1      NaN    NaN                                NaN     en
# 1                 1      NaN    NaN                                NaN     en
# 2                 2      NaN    NaN                                NaN     en
# 3                 0      NaN    NaN                                NaN     en
# 4                 0      NaN    NaN                                NaN     en
# ...             ...      ...    ...                                ...    ...
# 1556249           0  fifties   male  German English,Non native speaker     en
# 1556250           0  fifties   male  German English,Non native speaker     en
# 1556251           0  fifties   male  German English,Non native speaker     en
# 1556252           0  fifties   male  German English,Non native speaker     en
# 1556253           0  fifties   male  German English,Non native speaker     en
#
#            segment
# 0              NaN
# 1              NaN
# 2        Benchmark
# 3              NaN
# 4              NaN
# ...            ...
# 1556249        NaN
# 1556250        NaN
# 1556251        NaN
# 1556252        NaN
# 1556253        NaN
#
# [1556254 rows x 10 columns]>

# %%
# unique contributors 
len(df['client_id'].unique())
# Out:
# 72627

# %%
# rows that have metadata 
len(df[df['age'].notna()])
# Out:
# 1040402

# %%
# get all the age ranges 
df['age'].unique()
# Out:
# array([nan, 'twenties', 'sixties', 'seventies', 'thirties', 'fourties',
#        'teens', 'fifties', 'eighties', 'nineties'], dtype=object)

# %%
# age ranges

print('teens: ', len(df.loc[df['age'] == 'teens']))
print('twenties: ', len(df.loc[df['age'] == 'twenties']))
print('thirties: ', len(df.loc[df['age'] == 'thirties']))
print('fourties: ', len(df.loc[df['age'] == 'fourties']))
print('fifties: ', len(df.loc[df['age'] == 'fifties']))
print('sixties: ', len(df.loc[df['age'] == 'sixties']))
print('seventies: ', len(df.loc[df['age'] == 'seventies']))
print('eighties: ', len(df.loc[df['age'] == 'eighties']))
print('nineties: ', len(df.loc[df['age'] == 'nineties']))

print('NaN: ', len(df.loc[df['age'].isna()]))
# Out:
# teens:  94654
# twenties:  393510
# thirties:  221009
# fourties:  156949
# fifties:  83005
# sixties:  76483
# seventies:  12992
# eighties:  1691
# nineties:  109
# NaN:  577475

# %%
# get the genders 

df['gender'].unique()
# Out:
# array([nan, 'male', 'female', 'other'], dtype=object)

# %%
# genders

print('female: ', len(df.loc[df['gender'] == 'female']))
print('male: ', len(df.loc[df['gender'] == 'male']))
print('other: ', len(df.loc[df['gender'] == 'other']))

print('NaN: ', len(df.loc[df['gender'].isna()]))
# Out:
# female:  257655
# male:  754279
# other:  30911
# NaN:  575032

# %%
# get the accents 

# df['accent'].unique()
# in CV9, this key changed to `accents`
df['accents'].unique()
# Out:
# array([nan, 'England English,United States English', 'Hong Kong English',
#        'England English', 'United States English',
#        'United States English,wolof', 'Australian English',
#        'Latin America,United States English',
#        'Southern African (South Africa, Zimbabwe, Namibia)',
#        'India and South Asia (India, Pakistan, Sri Lanka)',
#        'United States English,Colombia', 'Canadian English',
#        'Non native speaker from France', 'Scottish English',
#        'New York City', 'Filipino', 'French', 'Argentinian English',
#        "A'lo", 'Finnish',
#        'United States English,India and South Asia (India, Pakistan, Sri Lanka)',
#        'Singaporean English',
#        'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)',
#        'Hispanic/Latino',
#        'India and South Asia (India, Pakistan, Sri Lanka),England English',
#        'Non-native', 'Georgian English', 'Non native',
#        'United States English,Canadian English,Indo-Canadian English',
#        'New Zealand English', 'Malaysian English',
#        'United States English,California', 'Irish English', 'Chinese',
#        'England English,Midlands English', 'french accent',
#        'India and South Asia (India, Pakistan, Sri Lanka),United States English',
#        'United States English,England English', 'northern cali',
#        'nigeria english', 'English County Durham',
#        'Выраженный украинский акцент', 'Catalan', 'Polish English',
#        'European English,French,Romanian', 'Welsh English',
#        'Australian English,United States English', 'Latino',
#        'England English,Hong Kong English', 'British', 'German English',
#        'Nigerian ', 'Swedish English', 'Spanish bilingual',
#        'United States English,Variable',
#        'United States English,Silicon Valley Native',
#        'United States English,United States English. people say I sound like a surffer dude.',
#        'New Zealand English,United States English',
#        'Liverpudlian English',
#        'United States English,Scottish English,Irish English,England English',
#        'United States English,England English,Hong Kong English',
#        'German English,I am German and speak English as learned at school',
#        'English with Swiss german accent', 'Japanese English',
#        'Mild Northern England English', 'England non-native',
#        'England English,Educated,non regional', "Israeli's accent ",
#        'Dutch,European,Adjustable',
#        'United States English,southern, formal, sultry',
#        'Australian English,New Zealand English',
#        'India and South Asia (India, Pakistan, Sri Lanka),Basic',
#        'East London ',
#        'United States English,Midwest USA speech blended with South Texas USA speech',
#        'German Accent', 'Not bad',
#        'United States English,Midwest US... With some Canadian slang. ',
#        'West Indian', 'United States English,Northern,Urban',
#        'British English with a little bit of Russian',
#        'United States English,Filipino', 'Northern Irish',
#        'United States English combined with European English',
#        'International English,United States English,Australian English',
#        'United States English,England English,India and South Asia (India, Pakistan, Sri Lanka)',
#        'Hong Kong English,Scottish English',
#        'South Atlantic (Falkland Islands, Saint Helena)',
#        'United States English,southern United States', 'Russian',
#        'United States English,pin/pen merger',
#        'United States English,Southern Appalachian English,Southern United States English',
#        'United States English,United States English Pacific Northwest',
#        'Southern Texas Accent,United States English',
#        'United States English,midwestern US',
#        'United States English,Midwest United States',
#        'United States English,Mix of voices', 'Colombian Accent',
#        'German', 'Slavic', 'Scottish English,Scottish',
#        'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad),Patois',
#        'India and South Asia (India, Pakistan, Sri Lanka),Indian with a tinge of an RP accent',
#        'Greek', 'United States English,Kenyan English',
#        'Afrikaans English', 'Transnational englishes blend',
#        'England English,London English',
#        'United States English,Midwestern',
#        "England English,Porto des dels 3 anys aprenent anglès a l'escola i actualment m'estic preparant per a l'examen del B2.",
#        'Bangladeshi,Bangladesh English', 'Russian,East Ukrainian ',
#        'England English,Southern England', 'England English,yorkshire',
#        'United States English,i have some pronunciation issues because of oral surgery and a hidden southern accent',
#        'United States English,little bit classy little bit sassy and add some city.....thats me',
#        "European,eastern europe,pronounced r's,heavy consonants ",
#        'Norwegian', 'English north of England ', 'Latin English',
#        'slighty Southern affected by decades in the Midwest, 4 years in Spain and Germany, speak some German, Spanish, Polish. Have lived in nine states.',
#        'East Indian', 'Australian English,England English,Japanese',
#        'french accent,French mid level accent', 'South African English',
#        'United States English,Australian English,England English,New Zealand English,India and South Asia (India, Pakistan, Sri Lanka),international,Slovak',
#        'United States English,Pittsburgh PA', 'polish accent',
#        'India and South Asia (India, Pakistan, Sri Lanka),Canadian English',
#        'Australian English,Educated Australian Accent',
#        'United States English,Midwestern United States English',
#        'Australian English,Sydney - middle eastern seaboard Australian',
#        'West African ', 'Latin American accent',
#        'England English,Lancashire, England ', 'Swedish accent', 'Kiwi',
#        'United States English,Canadian English', 'Slavic,Russian',
#        'Canadian English,United States English',
#        'Eastern European English', 'Singaporean English,England English',
#        'United States English,Australian English',
#        'United States English,Chicago ',
#        'United States English,American Midwest',
#        'Non-native,German Accent',
#        'United States English,Spoke Chinese when little,90% Pennsylvanian accent, 10% Chinese accent',
#        'England English,Scottish English',
#        'England English,South London and Essex',
#        'United States English,Canadian English,slight Brooklyn Accent',
#        'United States English,Chicano English,"Valley Girl" English',
#        'A variety of Texan English with some German influence that has undergone the cot-caught merger',
#        'United States English,new england/east coast',
#        'fluent,ESL,European', 'United States English,midwest',
#        'Australian English,England English',
#        'United States English,Israeli accent',
#        'United States English,Hmong-American',
#        'Singaporean English,Malaysian English',
#        'United States English,Okie', 'Kenyan ',
#        'Eastern European,Romanian', 'polish',
#        'Canadian English,Irish English', 'United States English,Cool',
#        'United States English,Mid-west United States English',
#        'England English,south German / Swiss accent',
#        'England English,British', 'serbian,United States English',
#        'England English,Welsh English',
#        'India and South Asia (India, Pakistan, Sri Lanka),bangladesh',
#        'Nigerian English', 'Filipino,United States English', 'Thai',
#        'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad),England English,Scottish English,United States English',
#        'With heavy Cantonese accent', 'england,london,academic',
#        'little latino,United States English,second language',
#        '2nd Language ',
#        'Canadian English,United States English,England English',
#        'India and South Asia (India, Pakistan, Sri Lanka),International Indian Accent',
#        'minor french accent', 'Upper Midwestern,United States English',
#        'Dutch English', 'Northern Irish,Norwegian,yorkshire',
#        'Malaysian English,England English',
#        'Mid-atlantic,England English,United States English',
#        'Midatlantic,England English', 'Italian',
#        'United States English,Californian Accent',
#        'United States English,Midwestern States (Michigan)', 'Ukrainian',
#        'Malaysian English,Javanese,Indonesian English',
#        'United States English,Slight lisp', 'Slavic,East European,polish',
#        'India and South Asia (India, Pakistan, Sri Lanka),try to maintain originality ',
#        'United States English,Some time spent in Scotland, mostly affecting inflection, I think',
#        'Austrian',
#        'Mid-Atlantic United States English,Philadelphia, Pennsylvania, United States English,United States English,Philadelphia Style United States English',
#        'United States English,South Texas,Slightly effeminate,Conversational',
#        'United States English,Midwestern US English (United States)',
#        'Slavic,polish', 'England English,southern english,sussex',
#        'England English,New Zealand English,Welsh English,Australian English,United States English,Mixed-Accent English',
#        'England English,Northern English',
#        'United States English,CARIBBEAN AND BRITISH MIXED WITH SOME NEW YORK ACCENTS',
#        'Spanish,Foreign,Non-native',
#        'England English,India and South Asia (India, Pakistan, Sri Lanka),Northern English',
#        'United States English,Pacific Northwest ', 'Bangladeshi English',
#        'German,south-west German,South German accent,Alemannic German Accent',
#        'European,German,Foreign,Non-native',
#        'United States English,Southern Californian', 'East African Khoja',
#        'Dutch', 'England English,Canadian English',
#        'United States English,Southwestern United States English',
#        'New Zealand English,England English',
#        'England English,South London', 'Northumbrian British English',
#        'United States English,Unite States Midwest',
#        'England English,Northern England',
#        'United States English,southern United States,New Orleans dialect',
#        'United States English,Midwestern,Minnesotan',
#        'United States English,Midwestern,Low,Demure',
#        'southern United States,United States English',
#        'England English,New Zealand English',
#        'Liverpool English,Lancashire English,England English',
#        'German English,Non native speaker'], dtype=object)

# %% [markdown]
# # TODO
#
# One of the things here that I need to do is get only the unique speaker ids for the accents - because you could have a speaker who has contributed a lot of _utterances_ and if we don't _only_ count _unique_ speakers, then this gives us a skewed understanding of the data.

# %%
# this gives us the unique LISTS
# but because each Speaker can specify MANY accents
# this is not granular enough for our needs. 

# This listing is also not sorted, so it's difficult to see which lists of accents
# occur at higher volumes.

# You can see in the output of this cell that the multiple accents are separated by commas
english_accents = df['accents'].unique()

for accent in english_accents:
    accent_total = len(df.loc[df['accents'] == accent])
    print(accent, ': ', accent_total)

print('NaN: ', len(df.loc[df['accents'].isna()]))
# Out:
# nan :  0
# England English,United States English :  86
# Hong Kong English :  4318
# England English :  134595
# United States English :  389397
# United States English,wolof :  1
# Australian English :  51593
# Latin America,United States English :  1
# Southern African (South Africa, Zimbabwe, Namibia) :  8485
# India and South Asia (India, Pakistan, Sri Lanka) :  101067
# United States English,Colombia :  1
# Canadian English :  61132
# Non native speaker from France :  1
# Scottish English :  15820
# New York City :  1
# Filipino :  5173
# French :  16
# Argentinian English :  1
# A'lo :  1
# Finnish :  1
# United States English,India and South Asia (India, Pakistan, Sri Lanka) :  6
# Singaporean English :  3402
# West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad) :  715
# Hispanic/Latino :  1
# India and South Asia (India, Pakistan, Sri Lanka),England English :  12
# Non-native :  1
# Georgian English :  1
# Non native :  1
# United States English,Canadian English,Indo-Canadian English :  1
# New Zealand English :  12381
# Malaysian English :  1810
# United States English,California :  1
# Irish English :  9607
# Chinese :  1
# England English,Midlands English :  1
# french accent :  3
# India and South Asia (India, Pakistan, Sri Lanka),United States English :  7
# United States English,England English :  174
# northern cali :  1
# nigeria english :  1
# English County Durham :  1
# Выраженный украинский акцент :  1
# Catalan :  1
# Polish English :  1
# European English,French,Romanian :  1
# Welsh English :  1759
# Australian English,United States English :  1
# Latino :  4
# England English,Hong Kong English :  2
# British :  2
# German English :  30
# Nigerian  :  2
# Swedish English :  2
# Spanish bilingual :  2
# United States English,Variable :  2
# United States English,Silicon Valley Native :  2
# United States English,United States English. people say I sound like a surffer dude. :  2
# New Zealand English,United States English :  2
# Liverpudlian English :  2
# United States English,Scottish English,Irish English,England English :  2
# United States English,England English,Hong Kong English :  2
# German English,I am German and speak English as learned at school :  2
# English with Swiss german accent :  2
# Japanese English :  13
# Mild Northern England English :  2
# England non-native :  2
# England English,Educated,non regional :  2
# Israeli's accent  :  2
# Dutch,European,Adjustable :  2
# United States English,southern, formal, sultry :  2
# Australian English,New Zealand English :  2
# India and South Asia (India, Pakistan, Sri Lanka),Basic :  3
# East London  :  3
# United States English,Midwest USA speech blended with South Texas USA speech :  3
# German Accent :  10
# Not bad :  3
# United States English,Midwest US... With some Canadian slang.  :  3
Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad),England English,Scottish English,United States English :  18
# With heavy Cantonese accent :  19
# england,london,academic :  22
# little latino,United States English,second language :  22
# 2nd Language  :  22
# Canadian English,United States English,England English :  23
# India and South Asia (India, Pakistan, Sri Lanka),International Indian Accent :  23
# minor french accent :  24
# Upper Midwestern,United States English :  24
# Dutch English :  139
# Northern Irish,Norwegian,yorkshire :  27
# Malaysian English,England English :  31
# Mid-atlantic,England English,United States English :  31
# Midatlantic,England English :  33
# Italian :  36
# United States English,Californian Accent :  37
# United States English,Midwestern States (Michigan) :  39
# Ukrainian :  39
# Malaysian English,Javanese,Indonesian English :  40
# United States English,Slight lisp :  43
# Slavic,East European,polish :  46
# India and South Asia (India, Pakistan, Sri Lanka),try to maintain originality  :  46
# United States English,Some time spent in Scotland, mostly affecting inflection, I think :  46
# Austrian :  118
# Mid-Atlantic United States English,Philadelphia, Pennsylvania, United States English,United States English,Philadelphia Style United States English :  52
# United States English,South Texas,Slightly effeminate,Conversational :  57
# United States English,Midwestern US English (United States) :  59
# Slavic,polish :  62
# England English,southern english,sussex :  65
# England English,New Zealand English,Welsh English,Australian English,United States English,Mixed-Accent English :  67
# England English,Northern English :  69
# United States English,CARIBBEAN AND BRITISH MIXED WITH SOME NEW YORK ACCENTS :  69
# Spanish,Foreign,Non-native :  69
# England English,India and South Asia (India, Pakistan, Sri Lanka),Northern English :  72
# United States English,Pacific Northwest  :  73
# Bangladeshi English :  74
# German,south-west German,South German accent,Alemannic German Accent :  74
# European,German,Foreign,Non-native :  92
# United States English,Southern Californian :  105
# East African Khoja :  108
# Dutch :  108
# England English,Canadian English :  132
# United States English,Southwestern United States English :  135
# New Zealand English,England English :  145
# England English,South London :  148
# Northumbrian British English :  163
# United States English,Unite States Midwest :  180
# England English,Northern England :  188
# United States English,southern United States,New Orleans dialect :  233
# United States English,Midwestern,Minnesotan :  276
# United States English,Midwestern,Low,Demure :  379
# southern United States,United States English :  391
# England English,New Zealand English :  2074
# Liverpool English,Lancashire English,England English :  2625
# German English,Non native speaker :  42001
# NaN:  756743

# %%
# So what we want to do here is put them into another list
# So that we can then order that list 

english_accents = df['accents'].unique()

english_accents_dict = {} 
english_accents_list = []
english_accents_list_by_total =[]

for accent in english_accents:
    accent_total = len(df.loc[df['accents'] == accent])
    english_accents_dict[accent] = accent_total
    
# Dict structures in Python are not sortable
# So we're going to iterate so that we can have a sorted list 

for accent_total in english_accents_dict.items(): 
    english_accents_list.append(accent_total)

print ('\n')
print ('breakpoint 1')
print ('\n')

# print the list 
#print(english_accents_list)
    
# Now, we want to order the list
# But if we use sort(), it will sort by the first element, which is the accent itself
# But we want to sort on the number of occurrences of that accent 

for accents_list in english_accents_list: 
    #print(accents_list)
    reversed = accents_list[::-1] # they're tuples, reverse() won't work
    #print(reversed)
    english_accents_list_by_total.append(reversed)
    
english_accents_list_by_total.sort(reverse=True)
    
print ('\n')
print ('breakpoint 2')
print ('\n')

# print the size of the list     
print(len(english_accents_list_by_total))

# print the sorted list
West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad),Patois': 4, 'India and South Asia (India, Pakistan, Sri Lanka),Indian with a tinge of an RP accent': 4, 'Greek': 4, 'United States English,Kenyan Engl ...
# NaN:  756743

# %%
# if a data contributor has specified multiple accents, 
# they are given as items in a list 
# so we need to get all the items out to count their occurrences 
# we can also use this to count co-occurences of accents in a single speaker 
for accent_list in english_accent_lists:
    accent_total = len(df.loc[df['accents'] == accent])
    print(accent, ': ', accent_total)

# %%
# french accents 

french_accents = df['accent'].unique()
for accent in french_accents:
    accent_total = len(df.loc[df['accent'] == accent])
    print(accent, ': ', accent_total)

print('NaN: ', len(df.loc[df['accent'].isna()]))
# Out:
# nan :  0
# canada :  8682
# france :  347436
# belgium :  9679
# cote_d_ivoire :  104
# senegal :  41
# algeria :  354
# burundi :  1
# united_kingdom :  259
# cameroon :  56
# united_states :  751
# reunion :  1053
# germany :  274
# romania :  121
# morocco :  59
# tunisia :  16
# switzerland :  3989
# martinique :  68
# other :  43
# guadeloupe :  133
# new_caledonia :  144
# benin :  996
# congo_brazzaville :  5
# monaco :  109
# gabon :  5
# luxembourg :  14
# st_pierre_et_miquelon :  6
# mayotte :  6
# italy :  57
# congo_kinshasa :  10
# ireland :  14
# haiti :  34
# madagascar :  162
# portugal :  17
# netherlands :  81
# french_guiana :  115
# NaN:  167394

# %%
# german accents 

german_accents = df['accent'].unique()
for accent in german_accents:
    accent_total = len(df.loc[df['accent'] == accent])
    print(accent, ': ', accent_total)

print('NaN: ', len(df.loc[df['accent'].isna()]))
# Out:
# nan :  0
# russia :  940
# germany :  437712
# france :  1405
# switzerland :  8602
# austria :  20659
# bulgaria :  1
# netherlands :  75
# denmark :  1
# poland :  103
# turkey :  24
# united_kingdom :  148
# czechia :  37
# united_states :  268
# greece :  120
# hungary :  151
# other :  184
# belgium :  9
# slovakia :  62
# lithuania :  5
# luxembourg :  57
# canada :  98
# liechtenstein :  62
# slovenia :  10
# brazil :  12
# italy :  978
# finland :  31
# NaN:  213040

# %%
# spanish accents 

spanish_accents = df['accent'].unique()
for accent in spanish_accents:
    accent_total = len(df.loc[df['accent'] == accent])
    print(accent, ': ', accent_total)

print('NaN: ', len(df.loc[df['accent'].isna()]))
# Out:
# mexicano :  16924
# nan :  0
# americacentral :  5532
# andino :  13729
# caribe :  8235
# centrosurpeninsular :  8713
# rioplatense :  12102
# chileno :  5316
# surpeninsular :  32622
# nortepeninsular :  35345
# canario :  952
# filipinas :  342
# NaN:  131198

# %%
# english accents 

english_accents = df['accent'].unique()
for accent in english_accents:
    accent_total = len(df.loc[df['accent'] == accent])
    print(accent, ': ', accent_total)

print('NaN: ', len(df.loc[df['accent'].isna()]))
# Out:
# nan :  0
# hongkong :  2750
# us :  351472
# england :  118401
# african :  8066
# indian :  73030
# other :  10505
# australia :  46951
# canada :  48453
# scotland :  12676
# philippines :  4158
# singapore :  2967
# bermuda :  643
# newzealand :  11281
# malaysia :  1685
# ireland :  9233
# wales :  1550
# southatlandtic :  203
# NaN:  721760
